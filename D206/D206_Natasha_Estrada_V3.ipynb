# %% [markdown]
# ## Import package statements and user defined functions

# %%
# !pip install scikit-learn==1.1.2
# Out:
# Requirement already satisfied: scikit-learn==1.1.2 in c:\users\nestr\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\nestr\anaconda3\lib\site-packages (from scikit-learn==1.1.2) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nestr\anaconda3\lib\site-packages (from scikit-learn==1.1.2) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nestr\anaconda3\lib\site-packages (from scikit-learn==1.1.2) (1.21.5)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\nestr\anaconda3\lib\site-packages (from scikit-learn==1.1.2) (1.1.1)

# %%
# !pip install scipy==1.9.1
# Out:
# Requirement already satisfied: scipy==1.9.1 in c:\users\nestr\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\nestr\anaconda3\lib\site-packages (from scipy==1.9.1) (1.21.5)

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\nestr\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: matplotlib in c:\users\nestr\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: numpy in c:\users\nestr\anaconda3\lib\site-packages (from missingno) (1.21.5)
# Requirement already satisfied: scipy in c:\users\nestr\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: seaborn in c:\users\nestr\anaconda3\lib\site-packages (from missingno) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nestr\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\nestr\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nestr\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\nestr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
# !pip install missingpy==0.2.0
# Out:
# Requirement already satisfied: missingpy==0.2.0 in c:\users\nestr\anaconda3\lib\site-packages (0.2.0)

# %%
# !pip show scipy missingpy scikit-learn missingno
# Out:
# Name: scipy
# Version: 1.9.1
# Summary: SciPy: Scientific Library for Python
# Home-page: https://www.scipy.org
# Author:
# Author-email:
# License: BSD
# Location: c:\users\nestr\anaconda3\lib\site-packages
# Requires: numpy
# Required-by: datashader, gensim, missingno, scikit-image, scikit-learn, statsmodels
# ---
# Name: missingpy
# Version: 0.2.0
# Summary: Missing Data Imputation for Python
# Home-page: https://github.com/epsilon-machine/missingpy
# Author: Ashim Bhattarai
# Author-email:
# License: UNKNOWN
# Location: c:\users\nestr\anaconda3\lib\site-packages
# Requires:
# Required-by:
# ---
# Name: scikit-learn
# Version: 1.1.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: c:\users\nestr\anaconda3\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: scikit-learn-intelex
# ---
# Name: missingno
# Version: 0.5.2
# Summary: Missing data visualization module for Python.
# Home-page: https://github.com/ResidentMario/missingno
# Author: Aleksey Bilogur
# Author-email: aleksey.bilogur@gmail.com
# License: MIT License
# Location: c:\users\nestr\anaconda3\lib\site-packages
# Requires: matplotlib, numpy, scipy, seaborn
# Required-by:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\nestr\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nestr\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\nestr\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nestr\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\nestr\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install pytest-warnings
# Out:
# Requirement already satisfied: pytest-warnings in c:\users\nestr\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: pytest in c:\users\nestr\anaconda3\lib\site-packages (from pytest-warnings) (7.1.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.1.1)
# Requirement already satisfied: packaging in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (1.4.0)
# Requirement already satisfied: colorama in c:\users\nestr\anaconda3\lib\site-packages (from pytest->pytest-warnings) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\nestr\anaconda3\lib\site-packages (from packaging->pytest->pytest-warnings) (3.0.9)

# %%
#Import packages
import pandas as pd
import warnings
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.neighbors._base
import sys
import numpy as np
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
from missingpy import MissForest
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
#Options

#Ensures pandas dataframes aren't truntuacted
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # default='warn'

# Function to identify potential outliers in a column using IQR method
def identify_outliers_iqr(column_data):
    Q1 = column_data.quantile(0.25)
    Q3 = column_data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column_data[(column_data < lower_bound) | (column_data > upper_bound)]

# %% [markdown]
# #  **Part I: Research Question**

# %% [markdown]
# Does the administration of vitamin D supplements impact readmission rates or the severity of complications for specific medical conditions?

# %% [markdown]
# ## Section B: Variables Description
#
# Describe all variables in the data set (regardless of the research question) and indicate the data type for each variable. Use examples from the data set to support your claims.

# %% [markdown]
# ## Data Dictionary
#
#
# The data set includes the following information:
# - Patients who are readmitted to the hospital within a month of release (the "ReAdmis" column)
# - Patient medical conditions (high blood pressure, stroke, obesity, arthritis, diabetes, etc.)
# - Patient information (service they received while hospitalized, days in hospital, type of initial admission, etc.)
# - Patient demographic information (gender, age, job, education level, etc.)
#
# The data set consists of 10,000 customers and 50 columns/variables.
#
# | Column              | Description                                                           | Type        | Example     |
# |---------------------|-----------------------------------------------------------------------|-------------|-------------|
# | Unnamed: 0          | A placeholder variable to preserve the original order of the raw data file | Quantitative | 1           |
# | CaseOrder           | A unique identifier for each case                                      | Quantitative | 1           |
# | Customer_id         | Unique patient ID                                                     | Qualitative | C412403     |
# | Interaction         | Unique IDs related to patient transactions procedures and admissions  | Qualitative | 8cd49b13-f45a-4b47-a2bd-173ffa932c2f |
# | UID                 | Unique identifier                                                     | Qualitative | 3a83ddb66e2ae73798bdf1d705dc0932 |
# | City                | Patient city of residence as listed on the billing statement          | Qualitative | Eva         |
# | State               | Patient state of residence as listed on the billing statement         | Qualitative | AL          |
# | County              | Patient county of residence as listed on the billing statement        | Qualitative | Morgan      |
# | Zip                 | Patient zip code of residence as listed on the billing statement      | Qualitative| 35621       |
# | Lat                 | GPS coordinates of patient residence as listed on the billing statement | Quantitative | 34.34960    |
# | Lng                 | GPS coordinates of patient residence as listed on the billing statement | Quantitative | -86.72508   |
# | Population          | Population within a mile radius of the patient, based on census data  | Quantitative | 11303       |
# | Area                | Area type (urban, suburban) based on unofficial census data            | Qualitative | Urban       |
# | Timezone            | Time zone of patient residence based on patient's sign up information | Qualitative | America/Chicago |
# | Job                 | Job of the patient (or primary insurance holder) as reported in the admissions information | Qualitative | Psychologist, sport and exercise |
# | Children            | Number of children in the patient's household as reported in the admissions information | Quantitative | 1.0         |
# | Age                 | Age of the patient as reported in admissions information              | Quantitative | 53.0        |
# | Education           | Highest earned degree of the patient as reported in admissions information | Qualitative | Some College, Less than 1 Year |
# | Employment          | Employment status of the patient as reported in admissions information | Qualitative | Full Time   |
# | Income              | Annual income of the patient (or primary insurance holder) as reported at the time of admission | Quantitative | 86575.93   |
# | Marital             | Marital status of the patient (or primary insurance holder) as reported on admission information | Qualitative | Divorce     |
# | Gender              | Customer self-identification as male, female, or nonbinary            | Qualitative | Male        |
# | ReAdmis             | Whether the patient was readmitted within a month of release or not   | Qualitative | No          |
# | VitD_levels         | The patient's vitamin D levels as measured in ng/mL                   | Quantitative | 17.80233    |
# | Doc_visits          | Number of times the primary physician visited the patient during the initial hospitalization | Quantitative | 5           |
# | Full_meals_eaten    | Number of full meals the patient ate while hospitalized (partial meals count as 0, and some patients had more than three meals in a day if requested) | Quantitative | 3 |
# | VitD_supp           | The number of times that vitamin D supplements were administered to the patient | Quantitative | 2           |
# | Soft_drink          | Whether the patient habitually drinks three or more sodas in a day    | Qualitative | No          |
# | Initial_admin       | The means by which the patient was admitted into the hospital initially (emergency admission, elective admission, observation) | Qualitative | Emergency   |
# | HighBlood           | Whether the patient has high blood pressure                           | Qualitative | Yes         |
# | Stroke              | Whether the patient has had a stroke                                   | Qualitative | No          |
# | Complication_risk   | Level of complication risk for the patient as assessed by a primary patient assessment (high, medium, low) | Qualitative | Medium      |
# | Overweight          | Whether the patient is considered overweight based on age, gender, and height | Qualitative | 0.0         |
# | Arthritis           | Whether the patient has arthritis                                      | Qualitative | Yes         |
# | Diabetes            | Whether the patient has diabetes                                       | Qualitative | Yes         |
# | Hyperlipidemia      | Whether the patient has hyperlipidemia                                 | Qualitative | Yes         |
# | BackPain            | Whether the patient has chronic back pain                              | Qualitative | Yes         |
# | Anxiety             | Whether the patient has an anxiety disorder                            | Quantitative | 1           |
# | Allergic_rhinitis   | Whether the patient has allergic rhinitis                              | Qualitative | Yes         |
# | Reflux_esophagitis  | Whether the patient has reflux esophagitis                             | Qualitative | No          |
# | Asthma              | Whether the patient has asthma                                         | Qualitative | No          |
# | Services            | Primary service the patient received while hospitalized (blood work, intravenous, CT scan, MRI) | Qualitative | Blood Work  |
# | Initial_days        | The number of days the patient stayed in the hospital during the initial visit | Quantitative | 9.058210335 |
# | TotalCharge         | The amount charged to the patient daily. This value reflects an average per patient based on the total charge divided by the number of days hospitalized. | Quantitative | 3533.292197 |
# | Additional_charges  | The average amount charged to the patient for miscellaneous procedures, treatments, medicines, anesthesiology, etc | Quantitative | 16815.5136 |
# | Item1               | Rating for the importance of Timely admission                          | Quantitative | 1           |
# | Item2               | Rating for the importance of Timely treatment                          | Quantitative | 2           |
# | Item3               | Rating for the importance of Timely visits                             | Quantitative | 3           |
# | Item4               | Reliability                                                          | Quantitative | 3           |
# | Item5               | Options                                                              | Quantitative | 6           |
# | Item6               | Hours of treatment                                                   | Quantitative | 7           |
# | Item7               | Courteous staff                                                      | Quantitative | 1           |
# | Item8               | Evidence of active listening from doctor                              | Quantitative | 1           |

# %% [markdown]
# # **Part II: Data-Cleaning Plan**

# %% [markdown]
# ## Section C: Data Cleaning Plan Explanation

# %% [markdown]
# ### **Subsection C1: Data Quality Assessment Plan**

# %% [markdown]
# **Visual Assessment:**
# Visual inspection allows me to quickly get an overview of the data and identify potential issues that may not be immediately apparent from summary statistics. I will use visualizations such as:
#
# **Sample Rows:** Displaying a sample of the data using head(), tail(), and sample() to observe the actual values and formats of the data.
#
# **Missing Value Patterns:** Visualizing missing values using the missingno library to identify any patterns or clusters of missing data.
#
# **Distribution Plots:** Creating histograms and box plots to check the distribution of numerical variables and identify potential outliers or skewness.
#
# **Categorical Plots:** Using bar charts or count plots to examine the distribution of categorical variables and detect any unexpected or inconsistent categories.
#
# **Programmatic Assessment:**
# The programmatic approach helps to systematically identify specific issues and gather quantitative information about the data. I will perform the following:
#
# **Data Types:** Using the info() attribute of the DataFrame to verify the correct data types for each column.
#
# **Missing Values:** Utilizing the isnull() function to identify missing values in each column and then counting the number of missing values using sum().
#
# **Duplicate Rows:** Checking for duplicate rows using the duplicated() function and counting the occurrences of duplicates using sum().
#
# **Data Summary:** Employing the info() and describe() functions to obtain data types, non-null counts, and summary statistics for numerical columns.
#
# **Categorical Values:** Using value_counts() to count unique values for categorical columns and check for any unexpected or inconsistent categories.
#
# **Checking for Outliers**

# %% [markdown]
# ### Subsection C2: Justification for Data Quality Assessment Approach

# %% [markdown]
# **Explain the characteristics of the data being assessed:**
#
# Based on the .info(), the dataset consists of 10,000 rows and 53 columns. Here are some key characteristics of the data being assessed:
#
# **Data Types:** The dataset contains columns with different data types, such as integers (int64), floating-point numbers (float64), and objects (object). The object type typically represents string or categorical data.
#
# **Missing Values:** Some columns have missing values. For example, the "Children," "Age," "Income," "Soft_drink," "Overweight," "Anxiety," "Initial_days" columns have missing values.
#
# **Geographic Information:** The dataset contains geographic information such as "City," "State," "County," "Zip," "Lat," and "Lng."
#
# **Demographic Information:** There are columns related to demographic information such as "Job," "Education," "Employment," "Marital," and "Gender."
#
# **Health-related Information:** Several columns contain health-related information, including "VitD_levels," "Doc_visits," "Full_meals_eaten," "VitD_supp," "HighBlood," "Stroke," "Complication_risk," "Arthritis," "Diabetes," "Hyperlipidemia," "BackPain," "Allergic_rhinitis," "Reflux_esophagitis," and "Asthma."
#
# **Medical Services and Charges:** The dataset includes information about medical services, charges, and items used, such as "Services," "Initial_days," "TotalCharge," "Additional_charges," and various "Item" columns.

# %% [markdown]
# **Justification:**
#
# By combining both visual and programmatic assessments, I can get a comprehensive understanding of the data's quality from different perspectives.
#
# Visualizations help identify patterns and outliers that may not be evident in summary statistics alone.
#
# Programmatic assessment provides concrete numbers and statistics for missing values, duplicates, and data types.
#
# The approach is scalable and can be applied to large datasets efficiently.
#
# The combination of visual and programmatic assessments ensures that potential data issues are not overlooked, and any identified quality issues can be addressed during the data cleaning process.

# %% [markdown]
# ### Subsection C3: Justification for Selected Programming Language and Libraries

# %% [markdown]
# **Justification for Using Python for Data Cleaning:**
#
#
# Python is the ideal choice for cleaning the given dataset due to its rich ecosystem of data libraries, such as Pandas and NumPy. These libraries offer powerful tools for handling missing values, removing duplicates, transforming data, and validating data integrity. As the programming language I have the most experience with, using Python allows for a more efficient and effective data cleaning process, enabling me to quickly and confidently prepare the data for analysis.<P>
#
# For variable imputation I will use the MissForest package from missingpy

# %% [markdown]
# ### Subsection C4: Annotated Code for Data Quality Assessment

# %%
#Load dataset into pandas dataframe
df = pd.read_csv('medical_raw_data.csv')

# %% [markdown]
# ##### **Initial dataframe inspection**

# %% [markdown]
# Displaying a sample of the data using head(), tail(), and sample() to observe the actual values and formats of the data.

# %%
#Checking that the data frame has loaded correctly
df
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0              1          1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 1              2          2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 2              3          3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 3              4          4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 4              5          5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# ...          ...        ...         ...                                   ...
# 9995        9996       9996     B863060  a25b594d-0328-486f-a9b9-0567eb0f9723
# 9996        9997       9997     P712040  70711574-f7b1-4a17-b15f-48c54564b70f
# 9997        9998       9998     R778890  1d79569d-8e0f-4180-a207-d67ee4527d26
# 9998        9999       9999     E344109  f5a68e69-2a60-409b-a92f-ac0847b27db0
# 9999       10000      10000     I569847  bc482c02-f8c9-4423-99de-3db5e62a18d5
#
#                                    UID          City State        County  \
# 0     3a83ddb66e2ae73798bdf1d705dc0932           Eva    AL        Morgan
# 1     176354c5eef714957d486009feabf195      Marianna    FL       Jackson
# 2     e19a0fa00aeda885b8a436757e889bc9   Sioux Falls    SD     Minnehaha
# 3     cd17d7b6d152cb6f23957346d11c3f07  New Richland    MN        Waseca
# 4     d2f0425877b10ed6bb381f3e2579424a    West Point    VA  King William
# ...                                ...           ...   ...           ...
# 9995  39184dc28cc038871912ccc4500049e5       Norlina    NC        Warren
# 9996  3cd124ccd43147404292e883bf9ec55c        Milmay    NJ      Atlantic
# 9997  41b770aeee97a5b9e7f69c906a8119d7     Southside    TN    Montgomery
# 9998  2bb491ef5b1beb1fed758cc6885c167a         Quinn    SD    Pennington
# 9999  95663a202338000abdf7e09311c2a8a1    Coraopolis    PA     Allegheny
#
#         Zip       Lat        Lng  Population      Area          Timezone  \
# 0     35621  34.34960  -86.72508        2951  Suburban   America/Chicago
# 1     32446  30.84513  -85.22907       11303     Urban   America/Chicago
# 2     57110  43.54321  -96.63772       17125  Suburban   America/Chicago
# 3     56072  43.89744  -93.51479        2162  Suburban   America/Chicago
# 4     23181  37.59894  -76.88958        5287     Rural  America/New_York
# ...     ...       ...        ...         ...       ...               ...
# 9995  27563  36.42886  -78.23716        4762     Urban  America/New_York
# 9996   8340  39.43609  -74.87302        1251     Urban  America/New_York
# 9997  37171  36.36655  -87.29988         532     Rural   America/Chicago
# 9998  57775  44.10354 -102.01593         271     Rural    America/Denver
# 9999  15108  40.49998  -80.19959       41524     Urban  America/New_York
#
#                                        Job  Children   Age  \
# 0         Psychologist, sport and exercise       1.0  53.0
# 1             Community development worker       3.0  51.0
# 2                  Chief Executive Officer       3.0  53.0
# 3                      Early years teacher       0.0  78.0
# 4              Health promotion specialist       NaN  22.0
# ...                                    ...       ...   ...
# 9995                Programmer, multimedia       NaN  25.0
# 9996         Restaurant manager, fast food       4.0  87.0
# 9997            Psychologist, occupational       3.0   NaN
# 9998  Outdoor activities/education manager       3.0  43.0
# 9999            Sports development officer       8.0   NaN
#
#                                      Education Employment    Income  \
# 0               Some College, Less than 1 Year  Full Time  86575.93
# 1     Some College, 1 or More Years, No Degree  Full Time  46805.99
# 2     Some College, 1 or More Years, No Degree    Retired  14370.14
# 3                GED or Alternative Credential    Retired  39741.49
# 4                  Regular High School Diploma  Full Time   1209.56
# ...                                        ...        ...       ...
# 9995                         Bachelor's Degree    Student  45967.61
# 9996               Regular High School Diploma  Full Time  14983.02
# 9997               Regular High School Diploma  Full Time  65917.81
# 9998                         Bachelor's Degree  Full Time  29702.32
# 9999       9th Grade to 12th Grade, No Diploma  Full Time  62682.63
#
#         Marital  Gender ReAdmis  VitD_levels  Doc_visits  Full_meals_eaten  \
# 0      Divorced    Male      No    17.802330           6                 0
# 1       Married  Female      No    18.994640           4                 2
# 2       Widowed  Female      No    17.415889           4                 1
# 3       Married    Male      No    17.420079           4                 1
# 4       Widowed  Female      No    16.870524           5                 0
# ...         ...     ...     ...          ...         ...               ...
# 9995    Widowed    Male      No    16.481612           4                 2
# 9996    Widowed    Male     Yes    18.451601           5                 0
# 9997  Separated  Female     Yes    15.752751           4                 2
# 9998   Divorced    Male     Yes    21.956305           5                 2
# 9999  Separated  Female     Yes    20.421883           5                 0
#
#       VitD_supp Soft_drink          Initial_admin HighBlood Stroke  \
# 0             0        NaN    Emergency Admission       Yes     No
# 1             1         No    Emergency Admission       Yes     No
# 2             0         No     Elective Admission       Yes     No
# 3             0         No     Elective Admission        No    Yes
# 4             2        Yes     Elective Admission        No     No
# ...         ...        ...                    ...       ...    ...
# 9995          1         No    Emergency Admission       Yes     No
# 9996          0         No     Elective Admission       Yes     No
# 9997          0        Yes     Elective Admission       Yes     No
# 9998          1         No    Emergency Admission        No     No
# 9999          1         No  Observation Admission        No     No
#
#      Complication_risk  Overweight Arthritis Diabetes Hyperlipidemia BackPain  \
# 0               Medium         0.0       Yes      Yes             No      Yes
# 1                 High         1.0        No       No             No       No
# 2               Medium         1.0        No      Yes             No       No
# 3               Medium         0.0       Yes       No             No       No
# 4                  Low         0.0        No       No            Yes       No
# ...                ...         ...       ...      ...            ...      ...
# 9995            Medium         NaN        No       No             No       No
# 9996            Medium         1.0       Yes      Yes             No       No
# 9997              High         1.0        No       No             No       No
# 9998            Medium         1.0        No       No             No      Yes
# 9999               Low         1.0       Yes       No            Yes       No
#
#       Anxiety Allergic_rhinitis Reflux_esophagitis Asthma     Services  \
# 0         1.0               Yes                 No    Yes   Blood Work
# 1         NaN                No                Yes     No  Intravenous
# 2         NaN                No                 No     No   Blood Work
# 3         NaN                No                Yes    Yes   Blood Work
# 4         0.0               Yes                 No     No      CT Scan
# ...       ...               ...                ...    ...          ...
# 9995      1.0                No                Yes     No  Intravenous
# 9996      0.0                No                 No    Yes      CT Scan
# 9997      1.0               Yes                 No     No  Intravenous
# 9998      0.0                No                 No     No   Blood Work
# 9999      0.0               Yes                 No     No   Blood Work
#
#       Initial_days  TotalCharge  Additional_charges  Item1  Item2  Item3  \
# 0        10.585770  3191.048774        17939.403420      3      3      2
# 1        15.129562  4214.905346        17612.998120      3      4      3
# 2         4.772177  2177.586768        17505.192460      2      4      4
# 3         1.714879  2465.118965        12993.437350      3      5      5
# 4         1.254807  1885.655137         3716.525786      2      1      3
# ...            ...          ...                 ...    ...    ...    ...
# 9995     51.561217  6651.241294         8927.642189      3      2      2
# 9996     68.668237  7851.522660        28507.147340      3      3      4
# 9997           NaN  7725.953391        15281.214660      3      3      3
# 9998     63.356903  8462.831883         7781.678412      5      5      3
# 9999     70.850592  8700.856021        11643.189930      4      3      3
#
#       Item4  Item5  Item6  Item7  Item8
# 0         2      4      3      3      4
# 1         4      4      4      3      3
# 2         4      3      4      3      3
# 3         3      4      5      5      5
# 4         3      5      3      4      3
# ...     ...    ...    ...    ...    ...
# 9995      3      4      3      4      2
# 9996      2      5      3      4      4
# 9997      4      4      2      3      2
# 9998      4      4      3      4      3
# 9999      2      3      6      4      3
#
# [10000 rows x 53 columns]

# %%
#Visually inspecting the first 10 rows
df.head(10)
# Out:
#    Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0           1          1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 1           2          2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 2           3          3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 3           4          4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 4           5          5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# 5           6          6     S543885  e3b0a319-9e2e-4a23-8752-2fdc736c30f4
# 6           7          7     E543302  2fccb53e-bd9a-4eaa-a53c-9dfc0cb83f94
# 7           8          8     K477307  ab634508-dd8c-42e5-a4e4-d101a46f2431
# 8           9          9     Q870521  67b386eb-1d04-4020-9474-542a09d304e3
# 9          10         10     Z229385  5acd5dd3-f0ae-41c7-9540-cf3e4ecb2e27
#
#                                 UID          City State        County    Zip  \
# 0  3a83ddb66e2ae73798bdf1d705dc0932           Eva    AL        Morgan  35621
# 1  176354c5eef714957d486009feabf195      Marianna    FL       Jackson  32446
# 2  e19a0fa00aeda885b8a436757e889bc9   Sioux Falls    SD     Minnehaha  57110
# 3  cd17d7b6d152cb6f23957346d11c3f07  New Richland    MN        Waseca  56072
# 4  d2f0425877b10ed6bb381f3e2579424a    West Point    VA  King William  23181
# 5  03e447146d4a32e1aaf75727c3d1230c        Braggs    OK      Muskogee  74423
# 6  e4884a42ba809df6a89ded6c97f460d4      Thompson    OH        Geauga  44086
# 7  5f78b8699d1aa9b950b562073f629ca2     Strasburg    VA    Shenandoah  22641
# 8  e8e016144bfbe14974752d834f530e26   Panama City    FL           Bay  32404
# 9  687e7ba1b80022c310fa2d4b00db199a   Paynesville    MN       Stearns  56362
#
#         Lat       Lng  Population      Area          Timezone  \
# 0  34.34960 -86.72508        2951  Suburban   America/Chicago
# 1  30.84513 -85.22907       11303     Urban   America/Chicago
# 2  43.54321 -96.63772       17125  Suburban   America/Chicago
# 3  43.89744 -93.51479        2162  Suburban   America/Chicago
# 4  37.59894 -76.88958        5287     Rural  America/New_York
# 5  35.67302 -95.19180         981     Urban   America/Chicago
# 6  41.67511 -81.05788        2558     Rural  America/New_York
# 7  39.08062 -78.39150         479     Urban  America/New_York
# 8  30.20097 -85.50610       40029     Urban   America/Chicago
# 9  45.40325 -94.71424        5840     Urban   America/Chicago
#
#                                 Job  Children   Age  \
# 0  Psychologist, sport and exercise       1.0  53.0
# 1      Community development worker       3.0  51.0
# 2           Chief Executive Officer       3.0  53.0
# 3               Early years teacher       0.0  78.0
# 4       Health promotion specialist       NaN  22.0
# 5               Corporate treasurer       NaN  76.0
# 6                       Hydrologist       0.0  50.0
# 7                 Psychiatric nurse       7.0  40.0
# 8          Computer games developer       NaN  48.0
# 9       Production assistant, radio       2.0  78.0
#
#                                   Education Employment    Income  \
# 0            Some College, Less than 1 Year  Full Time  86575.93
# 1  Some College, 1 or More Years, No Degree  Full Time  46805.99
# 2  Some College, 1 or More Years, No Degree    Retired  14370.14
# 3             GED or Alternative Credential    Retired  39741.49
# 4               Regular High School Diploma  Full Time   1209.56
# 5               Regular High School Diploma    Retired       NaN
# 6                         Bachelor's Degree    Retired  10456.05
# 7                           Master's Degree  Full Time       NaN
# 8               Regular High School Diploma  Full Time  55586.48
# 9  Some College, 1 or More Years, No Degree  Full Time  38965.22
#
#          Marital  Gender ReAdmis  VitD_levels  Doc_visits  Full_meals_eaten  \
# 0       Divorced    Male      No    17.802330           6                 0
# 1        Married  Female      No    18.994640           4                 2
# 2        Widowed  Female      No    17.415889           4                 1
# 3        Married    Male      No    17.420079           4                 1
# 4        Widowed  Female      No    16.870524           5                 0
# 5  Never Married    Male      No    19.956143           6                 0
# 6  Never Married    Male      No    14.348350           6                 0
# 7       Divorced  Female      No    20.425926           7                 2
# 8        Widowed    Male      No    19.539212           6                 3
# 9  Never Married  Female      No    19.628554           7                 1
#
#    VitD_supp Soft_drink          Initial_admin HighBlood Stroke  \
# 0          0        NaN    Emergency Admission       Yes     No
# 1          1         No    Emergency Admission       Yes     No
# 2          0         No     Elective Admission       Yes     No
# 3          0         No     Elective Admission        No    Yes
# 4          2        Yes     Elective Admission        No     No
# 5          0         No  Observation Admission        No     No
# 6          0        NaN    Emergency Admission       Yes     No
# 7          0        NaN  Observation Admission        No     No
# 8          0         No    Emergency Admission        No     No
# 9          2         No    Emergency Admission       Yes     No
#
#   Complication_risk  Overweight Arthritis Diabetes Hyperlipidemia BackPain  \
# 0            Medium         0.0       Yes      Yes             No      Yes
# 1              High         1.0        No       No             No       No
# 2            Medium         1.0        No      Yes             No       No
# 3            Medium         0.0       Yes       No             No       No
# 4               Low         0.0        No       No            Yes       No
# 5            Medium         1.0       Yes      Yes             No      Yes
# 6               Low         1.0       Yes      Yes            Yes      Yes
# 7            Medium         1.0        No       No             No       No
# 8               Low         1.0        No       No            Yes       No
# 9              High         1.0        No       No             No       No
#
#    Anxiety Allergic_rhinitis Reflux_esophagitis Asthma     Services  \
# 0      1.0               Yes                 No    Yes   Blood Work
# 1      NaN                No                Yes     No  Intravenous
# 2      NaN                No                 No     No   Blood Work
# 3      NaN                No                Yes    Yes   Blood Work
# 4      0.0               Yes                 No     No      CT Scan
# 5      0.0               Yes                 No     No   Blood Work
# 6      1.0                No                Yes     No  Intravenous
# 7      0.0                No                 No     No  Intravenous
# 8      NaN                No                 No     No  Intravenous
# 9      0.0               Yes                Yes    Yes   Blood Work
#
#    Initial_days  TotalCharge  Additional_charges  Item1  Item2  Item3  Item4  \
# 0     10.585770  3191.048774        17939.403420      3      3      2      2
# 1     15.129562  4214.905346        17612.998120      3      4      3      4
# 2      4.772177  2177.586768        17505.192460      2      4      4      4
# 3      1.714879  2465.118965        12993.437350      3      5      5      3
# 4      1.254807  1885.655137         3716.525786      2      1      3      3
# 5      5.957250  2774.089920        12742.589910      4      5      4      4
# 6      9.058210  3533.292197        16815.513600      4      3      3      2
# 7           NaN  3316.400250         6930.572138      1      2      2      5
# 8      6.180339  2922.759667         8363.187290      3      3      2      3
# 9      1.632554  3709.547665        26225.989910      5      5      5      3
#
#    Item5  Item6  Item7  Item8
# 0      4      3      3      4
# 1      4      4      3      3
# 2      3      4      3      3
# 3      4      5      5      5
# 4      5      3      4      3
# 5      3      5      4      6
# 6      3      4      5      5
# 7      4      2      4      2
# 8      3      3      4      2
# 9      4      2      3      2

# %%
#Visually inspecting the last 10 rows
df.tail()
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 9995        9996       9996     B863060  a25b594d-0328-486f-a9b9-0567eb0f9723
# 9996        9997       9997     P712040  70711574-f7b1-4a17-b15f-48c54564b70f
# 9997        9998       9998     R778890  1d79569d-8e0f-4180-a207-d67ee4527d26
# 9998        9999       9999     E344109  f5a68e69-2a60-409b-a92f-ac0847b27db0
# 9999       10000      10000     I569847  bc482c02-f8c9-4423-99de-3db5e62a18d5
#
#                                    UID        City State      County    Zip  \
# 9995  39184dc28cc038871912ccc4500049e5     Norlina    NC      Warren  27563
# 9996  3cd124ccd43147404292e883bf9ec55c      Milmay    NJ    Atlantic   8340
# 9997  41b770aeee97a5b9e7f69c906a8119d7   Southside    TN  Montgomery  37171
# 9998  2bb491ef5b1beb1fed758cc6885c167a       Quinn    SD  Pennington  57775
# 9999  95663a202338000abdf7e09311c2a8a1  Coraopolis    PA   Allegheny  15108
#
#            Lat        Lng  Population   Area          Timezone  \
# 9995  36.42886  -78.23716        4762  Urban  America/New_York
# 9996  39.43609  -74.87302        1251  Urban  America/New_York
# 9997  36.36655  -87.29988         532  Rural   America/Chicago
# 9998  44.10354 -102.01593         271  Rural    America/Denver
# 9999  40.49998  -80.19959       41524  Urban  America/New_York
#
#                                        Job  Children   Age  \
# 9995                Programmer, multimedia       NaN  25.0
# 9996         Restaurant manager, fast food       4.0  87.0
# 9997            Psychologist, occupational       3.0   NaN
# 9998  Outdoor activities/education manager       3.0  43.0
# 9999            Sports development officer       8.0   NaN
#
#                                 Education Employment    Income    Marital  \
# 9995                    Bachelor's Degree    Student  45967.61    Widowed
# 9996          Regular High School Diploma  Full Time  14983.02    Widowed
# 9997          Regular High School Diploma  Full Time  65917.81  Separated
# 9998                    Bachelor's Degree  Full Time  29702.32   Divorced
# 9999  9th Grade to 12th Grade, No Diploma  Full Time  62682.63  Separated
#
#       Gender ReAdmis  VitD_levels  Doc_visits  Full_meals_eaten  VitD_supp  \
# 9995    Male      No    16.481612           4                 2          1
# 9996    Male     Yes    18.451601           5                 0          0
# 9997  Female     Yes    15.752751           4                 2          0
# 9998    Male     Yes    21.956305           5                 2          1
# 9999  Female     Yes    20.421883           5                 0          1
#
#      Soft_drink          Initial_admin HighBlood Stroke Complication_risk  \
# 9995         No    Emergency Admission       Yes     No            Medium
# 9996         No     Elective Admission       Yes     No            Medium
# 9997        Yes     Elective Admission       Yes     No              High
# 9998         No    Emergency Admission        No     No            Medium
# 9999         No  Observation Admission        No     No               Low
#
#       Overweight Arthritis Diabetes Hyperlipidemia BackPain  Anxiety  \
# 9995         NaN        No       No             No       No      1.0
# 9996         1.0       Yes      Yes             No       No      0.0
# 9997         1.0        No       No             No       No      1.0
# 9998         1.0        No       No             No      Yes      0.0
# 9999         1.0       Yes       No            Yes       No      0.0
#
#      Allergic_rhinitis Reflux_esophagitis Asthma     Services  Initial_days  \
# 9995                No                Yes     No  Intravenous     51.561217
# 9996                No                 No    Yes      CT Scan     68.668237
# 9997               Yes                 No     No  Intravenous           NaN
# 9998                No                 No     No   Blood Work     63.356903
# 9999               Yes                 No     No   Blood Work     70.850592
#
#       TotalCharge  Additional_charges  Item1  Item2  Item3  Item4  Item5  \
# 9995  6651.241294         8927.642189      3      2      2      3      4
# 9996  7851.522660        28507.147340      3      3      4      2      5
# 9997  7725.953391        15281.214660      3      3      3      4      4
# 9998  8462.831883         7781.678412      5      5      3      4      4
# 9999  8700.856021        11643.189930      4      3      3      2      3
#
#       Item6  Item7  Item8
# 9995      3      4      2
# 9996      3      4      4
# 9997      2      3      2
# 9998      3      4      3
# 9999      6      4      3

# %%
#Visually inspecting a sample of 10 rows
df.sample(10)
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 9345        9346       9346     L296452  e6908c14-ad6d-4ad3-b5f6-0b048bd36f61
# 9929        9930       9930     J648523  aed70e8d-8e14-47a2-837a-a706de744fab
# 1713        1714       1714     D226554  54cb2515-c823-47fc-a931-283982a727c2
# 4653        4654       4654     I497777  0794ea40-9cc3-49a6-a077-cd20e59b7ba7
# 8893        8894       8894     D796320  141eee63-bd85-409d-a3e3-2d245ad6e9f2
# 3487        3488       3488     F841021  8f453cb2-a0a1-423b-a4f4-2d66b8008af8
# 6405        6406       6406     W821331  f642d5bf-0957-434a-83f6-ab751cdd049d
# 7975        7976       7976     R919495  a4935c0c-fd69-46ba-93d5-285b938f8815
# 2618        2619       2619      H78049  80200ea1-fff9-4b49-84dc-5edc91262971
# 5697        5698       5698      F95659  6ff38b97-76f6-4417-8942-57bf9a0480bc
#
#                                    UID              City State         County  \
# 9345  0f329cd6ad1f3107f4dbc4a932dcbcd8             Ukiah    OR       Umatilla
# 9929  8196c681a279d18b340c7f0459ce6139         Hopatcong    NJ         Sussex
# 1713  794a979e8eb81eb52afe83af76b09dba           Livonia    LA  Pointe Coupee
# 4653  73f898b2e54632c90cab1116dd1d3c87     Jarrettsville    MD        Harford
# 8893  52b0322f6f1aec88d111799efc578329            Monroe    NC          Union
# 3487  bf80e033b8c30893383fdd8cd8aa57e5        Ferryville    WI       Crawford
# 6405  496bca130c446bffc8af4ae7eaed5352          Carriere    MS    Pearl River
# 7975  1bcab68df35f2c07b9a23aa984e9ddcd   Wisconsin Dells    WI         Juneau
# 2618  ed97aa820c99decd46fdb24d128054eb        Whitingham    VT        Windham
# 5697  c544ab61cdba2b347f714211347a6f67  North Sioux City    SD          Union
#
#         Zip       Lat        Lng  Population      Area             Timezone  \
# 9345  97880  45.08356 -118.89413         327  Suburban  America/Los_Angeles
# 9929   7843  40.93964  -74.65982       11451     Rural     America/New_York
# 1713  70755  30.59335  -91.53002        1941     Urban      America/Chicago
# 4653  21084  39.61638  -76.46409        7583     Rural     America/New_York
# 8893  28110  35.06750  -80.52704       53520     Urban     America/New_York
# 3487  54628  43.37293  -91.02467         867     Urban      America/Chicago
# 6405  39426  30.65372  -89.66107       18193  Suburban      America/Chicago
# 7975  53965  43.67535  -89.75561       10338     Rural      America/Chicago
# 2618   5361  42.78275  -72.87650        1169     Rural     America/New_York
# 5697  57049  42.52476  -96.50721        6399  Suburban      America/Chicago
#
#                                        Job  Children   Age  \
# 9345                      Graphic designer       0.0  26.0
# 9929               Housing manager/officer       0.0   NaN
# 1713  English as a second language teacher       0.0  23.0
# 4653              Teacher, adult education       NaN  72.0
# 8893               Agricultural consultant       NaN  86.0
# 3487                     Building surveyor       NaN  56.0
# 6405                    Jewellery designer       4.0   NaN
# 7975                Psychologist, forensic       1.0   NaN
# 2618                           Tax adviser       1.0  18.0
# 5697                          Nurse, adult       7.0  56.0
#
#                                      Education Employment    Income  \
# 9345       9th Grade to 12th Grade, No Diploma  Full Time  80266.56
# 9929                         Bachelor's Degree  Full Time  88732.14
# 1713            Some College, Less than 1 Year    Student  15197.56
# 4653                         Bachelor's Degree    Student  65754.18
# 8893                         Bachelor's Degree  Part Time  24217.45
# 3487            Some College, Less than 1 Year  Part Time   9341.40
# 6405  Some College, 1 or More Years, No Degree  Full Time  15788.22
# 7975               Regular High School Diploma  Full Time  53604.34
# 2618       9th Grade to 12th Grade, No Diploma  Full Time  13869.69
# 5697       9th Grade to 12th Grade, No Diploma  Full Time  30225.11
#
#             Marital  Gender ReAdmis  VitD_levels  Doc_visits  \
# 9345        Widowed    Male      No    18.838135           5
# 9929       Divorced  Female     Yes    44.494793           4
# 1713      Separated  Female      No    16.929801           4
# 4653        Widowed    Male      No    16.399462           5
# 8893        Widowed    Male     Yes    19.176188           7
# 3487        Widowed  Female      No    18.220475           4
# 6405        Married    Male     Yes    19.327414           6
# 7975  Never Married  Female     Yes    20.653928           4
# 2618       Divorced  Female      No    14.086635           5
# 5697        Married    Male     Yes    16.812557           5
#
#       Full_meals_eaten  VitD_supp Soft_drink          Initial_admin HighBlood  \
# 9345                 0          0         No  Observation Admission       Yes
# 9929                 3          0         No  Observation Admission        No
# 1713                 1          0         No    Emergency Admission       Yes
# 4653                 1          1         No    Emergency Admission       Yes
# 8893                 0          0        Yes  Observation Admission        No
# 3487                 2          1         No     Elective Admission       Yes
# 6405                 1          0        NaN     Elective Admission        No
# 7975                 0          0         No    Emergency Admission       Yes
# 2618                 3          0         No    Emergency Admission       Yes
# 5697                 1          0        NaN    Emergency Admission        No
#
#      Stroke Complication_risk  Overweight Arthritis Diabetes Hyperlipidemia  \
# 9345     No            Medium         1.0        No       No            Yes
# 9929     No               Low         0.0        No       No            Yes
# 1713    Yes              High         0.0        No       No             No
# 4653     No              High         1.0       Yes       No             No
# 8893     No            Medium         0.0       Yes       No             No
# 3487     No              High         0.0        No       No             No
# 6405     No            Medium         1.0        No      Yes            Yes
# 7975    Yes              High         1.0       Yes       No             No
# 2618     No              High         1.0        No       No             No
# 5697     No            Medium         0.0        No       No             No
#
#      BackPain  Anxiety Allergic_rhinitis Reflux_esophagitis Asthma  \
# 9345       No      0.0                No                Yes    Yes
# 9929       No      1.0                No                 No     No
# 1713       No      0.0                No                 No     No
# 4653      Yes      0.0               Yes                Yes     No
# 8893       No      1.0                No                 No     No
# 3487      Yes      1.0               Yes                Yes     No
# 6405       No      1.0               Yes                Yes     No
# 7975       No      0.0                No                Yes     No
# 2618       No      1.0                No                 No     No
# 5697       No      1.0               Yes                Yes     No
#
#          Services  Initial_days   TotalCharge  Additional_charges  Item1  \
# 9345   Blood Work     53.903570   6869.663653         8776.118480      4
# 9929      CT Scan     69.734824  18847.705170         7225.082587      3
# 1713  Intravenous      1.791892   3183.086694         9185.828580      5
# 4653   Blood Work      4.438179   3346.999347        24482.340770      4
# 8893   Blood Work     70.107059   7573.579144        14214.880700      5
# 3487   Blood Work      7.527123   3290.379199        18708.456300      3
# 6405   Blood Work     67.601272   8013.605643        14700.347790      3
# 7975  Intravenous     61.282001   8344.682714        29072.813850      4
# 2618  Intravenous      6.050085   2842.952012         6986.084510      4
# 5697      CT Scan           NaN   7366.161349         9995.650041      3
#
#       Item2  Item3  Item4  Item5  Item6  Item7  Item8
# 9345      4      5      4      3      4      3      4
# 9929      3      2      5      4      3      3      5
# 1713      6      5      4      3      3      4      2
# 4653      4      4      2      4      4      4      4
# 8893      6      6      4      5      4      5      5
# 3487      3      4      5      4      3      3      3
# 6405      3      4      4      3      3      2      3
# 7975      3      4      4      3      5      3      3
# 2618      5      5      4      3      5      4      6
# 5697      4      4      4      4      2      3      5

# %% [markdown]
# #### **Data Types**

# %%
#Checking shape, column names, datatypes and non null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10000 non-null  int64
#  1   CaseOrder           10000 non-null  int64
#  2   Customer_id         10000 non-null  object
#  3   Interaction         10000 non-null  object
#  4   UID                 10000 non-null  object
#  5   City                10000 non-null  object
#  6   State               10000 non-null  object
#  7   County              10000 non-null  object
#  8   Zip                 10000 non-null  int64
#  9   Lat                 10000 non-null  float64
#  10  Lng                 10000 non-null  float64
#  11  Population          10000 non-null  int64
#  12  Area                10000 non-null  object
#  13  Timezone            10000 non-null  object
#  14  Job                 10000 non-null  object
#  15  Children            7412 non-null   float64
#  16  Age                 7586 non-null   float64
#  17  Education           10000 non-null  object
#  18  Employment          10000 non-null  object
#  19  Income              7536 non-null   float64
#  20  Marital             10000 non-null  object
#  21  Gender              10000 non-null  object
#  22  ReAdmis             10000 non-null  object
#  23  VitD_levels         10000 non-null  float64
#  24  Doc_visits          10000 non-null  int64
#  25  Full_meals_eaten    10000 non-null  int64
#  26  VitD_supp           10000 non-null  int64
#  27  Soft_drink          7533 non-null   object
#  28  Initial_admin       10000 non-null  object
#  29  HighBlood           10000 non-null  object
#  30  Stroke              10000 non-null  object
#  31  Complication_risk   10000 non-null  object
#  32  Overweight          9018 non-null   float64
#  33  Arthritis           10000 non-null  object
#  34  Diabetes            10000 non-null  object
#  35  Hyperlipidemia      10000 non-null  object
#  36  BackPain            10000 non-null  object
#  37  Anxiety             9016 non-null   float64
#  38  Allergic_rhinitis   10000 non-null  object
#  39  Reflux_esophagitis  10000 non-null  object
#  40  Asthma              10000 non-null  object
#  41  Services            10000 non-null  object
#  42  Initial_days        8944 non-null   float64
#  43  TotalCharge         10000 non-null  float64
#  44  Additional_charges  10000 non-null  float64
#  45  Item1               10000 non-null  int64
#  46  Item2               10000 non-null  int64
#  47  Item3               10000 non-null  int64
#  48  Item4               10000 non-null  int64
#  49  Item5               10000 non-null  int64
#  50  Item6               10000 non-null  int64
#  51  Item7               10000 non-null  int64
#  52  Item8               10000 non-null  int64
# dtypes: float64(11), int64(15), object(27)
# memory usage: 4.0+ MB

# %%
#Summary statistics
df.describe()
# Out:
#         Unnamed: 0    CaseOrder           Zip           Lat           Lng  \
# count  10000.00000  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000   5000.50000  50159.323900     38.751099    -91.243080
# std     2886.89568   2886.89568  27469.588208      5.403085     15.205998
# min        1.00000      1.00000    610.000000     17.967190   -174.209690
# 25%     2500.75000   2500.75000  27592.000000     35.255120    -97.352982
# 50%     5000.50000   5000.50000  50207.000000     39.419355    -88.397230
# 75%     7500.25000   7500.25000  72411.750000     42.044175    -80.438050
# max    10000.00000  10000.00000  99929.000000     70.560990    -65.290170
#
#           Population     Children          Age         Income   VitD_levels  \
# count   10000.000000  7412.000000  7586.000000    7536.000000  10000.000000
# mean     9965.253800     2.098219    53.295676   40484.438268     19.412675
# std     14824.758614     2.155427    20.659182   28664.861050      6.723277
# min         0.000000     0.000000    18.000000     154.080000      9.519012
# 25%       694.750000     0.000000    35.000000   19450.792500     16.513171
# 50%      2769.000000     1.000000    53.000000   33942.280000     18.080560
# 75%     13945.000000     3.000000    71.000000   54075.235000     19.789740
# max    122814.000000    10.000000    89.000000  207249.130000     53.019124
#
#          Doc_visits  Full_meals_eaten     VitD_supp   Overweight      Anxiety  \
# count  10000.000000      10000.000000  10000.000000  9018.000000  9016.000000
# mean       5.012200          1.001400      0.398900     0.709137     0.322316
# std        1.045734          1.008117      0.628505     0.454186     0.467389
# min        1.000000          0.000000      0.000000     0.000000     0.000000
# 25%        4.000000          0.000000      0.000000     0.000000     0.000000
# 50%        5.000000          1.000000      0.000000     1.000000     0.000000
# 75%        6.000000          2.000000      1.000000     1.000000     1.000000
# max        9.000000          7.000000      5.000000     1.000000     1.000000
#
#        Initial_days   TotalCharge  Additional_charges         Item1  \
# count   8944.000000  10000.000000        10000.000000  10000.000000
# mean      34.432082   5891.538261        12934.528586      3.518800
# std       26.287050   3377.558136         6542.601544      1.031966
# min        1.001981   1256.751699         3125.702716      1.000000
# 25%        7.911709   3253.239465         7986.487642      3.000000
# 50%       34.446941   5852.250564        11573.979365      4.000000
# 75%       61.124654   7614.989701        15626.491033      4.000000
# max       71.981486  21524.224210        30566.073130      8.000000
#
#               Item2         Item3         Item4         Item5         Item6  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.506700      3.511100      3.515100      3.496900      3.522500
# std        1.034825      1.032755      1.036282      1.030192      1.032376
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      3.000000      3.000000      3.000000      3.000000
# 50%        3.000000      4.000000      4.000000      3.000000      4.000000
# 75%        4.000000      4.000000      4.000000      4.000000      4.000000
# max        7.000000      8.000000      7.000000      7.000000      7.000000
#
#               Item7         Item8
# count  10000.000000  10000.000000
# mean       3.494000      3.509700
# std        1.021405      1.042312
# min        1.000000      1.000000
# 25%        3.000000      3.000000
# 50%        3.000000      3.000000
# 75%        4.000000      4.000000
# max        7.000000      7.000000

# %% [markdown]
# ##### **Distribution Plots**

# %% [markdown]
# Creating histograms and box plots to check the distribution of numerical variables and identify potential outliers or skewness.

# %%
# Create a list of numerical columns to be used in plots
numerical_columns = df.select_dtypes(include='number')

# %%
# Create histograms for all numerical columns
num_plots = len(numerical_columns.columns)
fig, axes = plt.subplots(nrows=num_plots, ncols=1, figsize=(8, 6*num_plots))

for i, column in enumerate(numerical_columns.columns):
    sns.histplot(data=numerical_columns, x=column, bins=20, ax=axes[i], color='blue')
    axes[i].set_title(column)
    axes[i].set_xlabel(None)  # Remove individual x-labels to avoid overlapping

plt.suptitle("Histograms of Numerical Variables", y=1.02)
plt.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots
plt.tight_layout()
plt.show()

# %%
# Columns to exclude from box plots
columns_to_exclude = ['Overweight', 'Anxiety','Zip','Unnamed: 0', 'CaseOrder', 'Zip','Lat', 'Lng']

# Remove the columns from the list
numerical_columns = numerical_columns.drop(columns=columns_to_exclude)

print(numerical_columns.columns.tolist())
# Out:
# ['Population', 'Children', 'Age', 'Income', 'VitD_levels', 'Doc_visits', 'Full_meals_eaten', 'VitD_supp', 'Initial_days', 'TotalCharge', 'Additional_charges', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5', 'Item6', 'Item7', 'Item8']

# %%
# Number of numerical columns and columns per row
num_columns = len(numerical_columns.columns)
columns_per_row = 5  # Adjust the number of columns per row as needed

# Calculate the number of rows for the grid layout
num_rows = (num_columns + columns_per_row - 1) // columns_per_row

# Create box plots for all numerical columns in a grid layout
fig, axes = plt.subplots(nrows=num_rows, ncols=columns_per_row, figsize=(15, 3*num_rows))

for i, column in enumerate(numerical_columns.columns):
    row_idx = i // columns_per_row
    col_idx = i % columns_per_row
    sns.boxplot(data=numerical_columns, x=column, ax=axes[row_idx, col_idx], color='blue' )
    axes[row_idx, col_idx].set_title(column)

# Remove any empty subplots
for i in range(num_columns, num_rows * columns_per_row):
    row_idx = i // columns_per_row
    col_idx = i % columns_per_row
    fig.delaxes(axes[row_idx, col_idx])

plt.suptitle("Box Plots of Quantitative Variables", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Categorical Plots**

# %% [markdown]
# Create a list of categorical columns

# %%
#Check the data types of all columns
data_types = df.dtypes

categorical_columns = []
for column in df.columns:
    if data_types[column] == 'object':  # Check for 'object' data type
        unique_count = df[column].nunique()
        total_count = df[column].count()
        if unique_count < 0.5 * total_count:
            categorical_columns.append(column)

print("Categorical columns:")
print(categorical_columns)

# Drop 'Job' and 'County' from the list of categorical columns
#Removing because Job and County have too many unique results to display clearly
categorical_columns.remove('Job')
categorical_columns.remove('County')
# Out:
# Categorical columns:
# ['State', 'County', 'Area', 'Timezone', 'Job', 'Education', 'Employment', 'Marital', 'Gender', 'ReAdmis', 'Soft_drink', 'Initial_admin', 'HighBlood', 'Stroke', 'Complication_risk', 'Arthritis', 'Diabetes', 'Hyperlipidemia', 'BackPain', 'Allergic_rhinitis', 'Reflux_esophagitis', 'Asthma', 'Services']

# %%
# Convert specified columns to categorical data type
df[categorical_columns] = df[categorical_columns].astype('category')

# Create bar charts for each categorical variable
tab10_colors = sns.color_palette("tab10")  # Get the colors from the 'tab10' palette
for column in categorical_columns:
    plt.figure(figsize=(10, 6))  # Increase the figure size
    value_counts = df[column].value_counts()
    ax = sns.barplot(x=value_counts.index, y=value_counts.values, palette=tab10_colors)  # Use the 'tab10' colors
    ax.set_title(column)
    plt.xticks(rotation=45, ha='right')  # Rotate and align the x-axis labels
    plt.tight_layout()  # Adjust spacing
    plt.show()

# %% [markdown]
# ##### **Missing Value Patterns**

# %%
matrix_plot = msno.matrix(df)

# Get the column labels (feature names)
column_labels = df.columns

plt.xlabel('Features', fontsize=12)
plt.ylabel('Observations', fontsize=12)
plt.title('Missing Data Matrix', fontsize=14)
plt.xticks(range(len(column_labels)), column_labels, rotation=90)  # Add x-axis tick labels

# Show the plot
plt.show()

# %%
msno.bar(df)      # Bar chart visualization
# Out:
# <AxesSubplot:>

# %%
#Identify the relationship of missing values between columns
msno.dendrogram(df, orientation='left')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Missing values are present in 7 different columns

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# CaseOrder                0
# Customer_id              0
# Interaction              0
# UID                      0
# City                     0
# State                    0
# County                   0
# Zip                      0
# Lat                      0
# Lng                      0
# Population               0
# Area                     0
# Timezone                 0
# Job                      0
# Children              2588
# Age                   2414
# Education                0
# Employment               0
# Income                2464
# Marital                  0
# Gender                   0
# ReAdmis                  0
# VitD_levels              0
# Doc_visits               0
# Full_meals_eaten         0
# VitD_supp                0
# Soft_drink            2467
# Initial_admin            0
# HighBlood                0
# Stroke                   0
# Complication_risk        0
# Overweight             982
# Arthritis                0
# Diabetes                 0
# Hyperlipidemia           0
# BackPain                 0
# Anxiety                984
# Allergic_rhinitis        0
# Reflux_esophagitis       0
# Asthma                   0
# Services                 0
# Initial_days          1056
# TotalCharge              0
# Additional_charges       0
# Item1                    0
# Item2                    0
# Item3                    0
# Item4                    0
# Item5                    0
# Item6                    0
# Item7                    0
# Item8                    0
# dtype: int64

# %% [markdown]
# **Columns with missing values**
#
# | Category      | Count     |
# |---------------|-----------|
# | Children      | 2588      |
# | Age           | 2414      |
# | Income        | 2464      |
# | Soft_drink    | 2467      |
# | Overweight    | 982       |
# | Anxiety       | 984       |
# | Initial_days  | 1056      |

# %% [markdown]
# **Checking how many rows have missing values**

# %%
# Check for rows with missing values
rows_with_missing_values = df[df.isnull().sum(axis=1) > 0]

count_missing_values = df.isnull().any(axis=1).sum()

print("Count of rows with missing values:", count_missing_values)

total_rows = df.shape[0]

# Calculate the percentage of rows with missing values
percentage_missing_values = (count_missing_values / total_rows) * 100

print("Percentage of rows with missing values:", percentage_missing_values, "%")
# Out:
# Count of rows with missing values: 7687
# Percentage of rows with missing values: 76.87 %

# %% [markdown]
# **Checking how many rows have more than one missing value**

# %%
# Check for rows with multiple missing values
rows_with_two_or_more_missing = df[df.isnull().sum(axis=1) >= 2]
rows_with_three_or_more_missing = df[df.isnull().sum(axis=1) >= 3]
rows_with_four_or_more_missing = df[df.isnull().sum(axis=1) >= 4]
rows_with_five_or_more_missing = df[df.isnull().sum(axis=1) >= 5]
rows_with_six_or_more_missing = df[df.isnull().sum(axis=1) >= 6]
rows_with_seven_or_more_missing = df[df.isnull().sum(axis=1) >= 7]

# Get count of rows with two or more missing values
count_rows_with_two_or_more_missing = len(df[df.isnull().sum(axis=1) >= 2])

# Get count of rows with three or more missing values
count_rows_with_three_or_more_missing = len(df[df.isnull().sum(axis=1) >= 3])

# Get count of rows with four or more missing values
count_rows_with_four_or_more_missing = len(df[df.isnull().sum(axis=1) >= 4])

# Get count of rows with five or more missing value
count_rows_with_five_or_more_missing = len(df[df.isnull().sum(axis=1) >= 5])

# Get count of rows with six or more missing value
count_rows_with_six_or_more_missing = len(df[df.isnull().sum(axis=1) >= 6])

# Get count of rows with five or more missing value
count_rows_with_seven_or_more_missing = len(df[df.isnull().sum(axis=1) >= 7])


print("Count of rows with two or more missing values:", count_rows_with_two_or_more_missing)
print("Count of rows with three or more missing values:", count_rows_with_three_or_more_missing)
print("Count of rows with four or more missing values:", count_rows_with_four_or_more_missing)
print("Count of rows with five or more missing values:", count_rows_with_five_or_more_missing)
print("Count of rows with six or more missing values:", count_rows_with_six_or_more_missing )
print("Count of rows with seven or more missing values:", count_rows_with_seven_or_more_missing)
# Out:
# Count of rows with two or more missing values: 3789
# Count of rows with three or more missing values: 1219
# Count of rows with four or more missing values: 237
# Count of rows with five or more missing values: 22
# Count of rows with six or more missing values: 1
# Count of rows with seven or more missing values: 0

# %% [markdown]
# **Inspecting rows with 5 or more missing values**

# %%
rows_with_five_or_more_missing
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 192          193        193     P165814  6fa35d15-2c60-4250-8e04-ab36c9d810ba
# 292          293        293     U325503  3908e8c3-8453-4197-b47d-cfebfc30e348
# 1177        1178       1178     F979938  792c513b-6a26-4296-9392-eb16b970a5da
# 1215        1216       1216      F54388  62c1ea6d-3913-438e-872f-9f8d51bcbf1f
# 1989        1990       1990     W646888  33faddfa-d4cb-40a8-802b-985fcac39e8b
# 2925        2926       2926     N691392  a73cf155-6b21-4415-aae8-ac2939862d9e
# 3718        3719       3719     C425801  42c6bf11-ed99-43ad-b8cd-3b62ac5ac0c5
# 4014        4015       4015     X526907  033dfb05-fb84-4e37-b601-c45079d2c106
# 4271        4272       4272     H662750  faf29a9a-e5f8-4c25-ab2c-3f786beb79ce
# 4301        4302       4302     L875305  e784c96b-fca0-49a6-90a1-f59a523bdd13
# 4958        4959       4959     O757195  de0fa49f-16d9-4b5b-948b-f19f7afb4e48
# 4999        5000       5000     V497546  50363f3b-92b5-4941-80c0-dfb759a4a635
# 5293        5294       5294     Z549880  8ab93805-f0ff-4bd3-b9b4-af2f82bb47e0
# 5598        5599       5599     S778225  90a133a1-6098-488a-95e9-553c3508c94d
# 5738        5739       5739     X860411  d9a81324-2384-4112-9118-23b4c05f4de5
# 6217        6218       6218     Q260831  dc6e49bd-3ae8-4557-bcbd-28d3cac29524
# 6420        6421       6421      X81207  78d03d59-a07b-4486-8098-e343fe8b722a
# 7984        7985       7985     W866195  da579013-be31-4755-bdc4-260f941c7feb
# 8281        8282       8282     K650263  52de3bc8-0268-4d3c-a650-406dbbca843b
# 8286        8287       8287     M737405  2a4f9fc1-8f2c-4e77-bca0-821b60f85e6c
# 8702        8703       8703     N195610  46f8dea5-4705-44ee-88d3-4e342b3e17be
# 9032        9033       9033     J399672  be095524-1b86-4036-87f1-88e368c6af4f
#
#                                    UID               City State      County  \
# 192   7e61fbd0b029abbbc81b59e0e5867987     Liberty Center    IN       Wells
# 292   db6d501f4135c61326945dbe705da6e3            Peytona    WV       Boone
# 1177  5d6e4b04462b2131bbc993a1ab115ba6     Grand Junction    CO        Mesa
# 1215  a4d849951263a259d1d18aaab7f3c702          Lewistown    PA     Mifflin
# 1989  a19e52d878627128cbe6462d28b30edc        West Newton    IN      Marion
# 2925  48e5392d0a06b109ed2cd29947e71297             Sadler    TX     Grayson
# 3718  b37d1b8e6fa302c947682f3f4d1ba49f           Marietta    GA        Cobb
# 4014  6a1c247257421c2b389253696450167b         Dixonville    PA     Indiana
# 4271  272ffe5b83f7a634c128573f31bef4a0          West York    IL    Crawford
# 4301  56306bc6b6debb0d73b9e872884f4c9e            Fairfax    CA       Marin
# 4958  cf8c7447028c7f48204e6513839d9f63            Madelia    MN    Watonwan
# 4999  fdacdfce808f974f996b73d9535f177d          Littleton    CO    Arapahoe
# 5293  c043122232f04d7706bf0a462b5487be       Little Falls    MN    Morrison
# 5598  b33dc7cbca7c4f8ff6fb17370d4430ae      Richardsville    VA    Culpeper
# 5738  737d326e4cff153c15bab10266c06cd5    West Brookfield    MA   Worcester
# 6217  6d64d0dd42e3d66e8c5d1e1c81d3bcca  Steamboat Springs    CO       Routt
# 6420  a9b0978c14b2ca17e2efb5832e5f8791           Sherwood    AR     Pulaski
# 7984  9094ebb78fe2a9f9afb7a1c6f597b112         Dillingham    AK  Dillingham
# 8281  ff3550d6bf087094b4e238e630a930ff        Guilderland    NY      Albany
# 8286  7c9e608f67cfba03f2bb8fe5e202c2ac           Davidson    OK     Tillman
# 8702  13e1eff81a0f5df86aa1a371b8e9a413         Waxahachie    TX       Ellis
# 9032  4c22d539012f2b9e77902b6aec8933ee         Valparaiso    FL    Okaloosa
#
#         Zip       Lat        Lng  Population      Area  \
# 192   46766  40.71204  -85.28477         865  Suburban
# 292   25154  38.11700  -81.70497         582     Rural
# 1177  81506  39.11585 -108.53246       11799  Suburban
# 1215  17044  40.57840  -77.59430       21047  Suburban
# 1989  46183  39.65280  -86.28160          15     Rural
# 2925  76264  33.73974  -96.83528        1508     Rural
# 3718  30008  33.89630  -84.58925       31982     Rural
# 4014  15734  40.72485  -79.00127         467  Suburban
# 4271  62478  39.17838  -87.74266         389     Rural
# 4301  94930  37.96512 -122.61277        8678     Urban
# 4958  56062  44.04739  -94.41483        3547     Rural
# 4999  80120  39.59330 -105.00956       31830     Urban
# 5293  56345  45.98881  -94.37486       14557     Rural
# 5598  22736  38.39739  -77.70495         737     Urban
# 5738   1585  42.24152  -72.16193        4574     Urban
# 6217  80477  40.48635 -106.82922         130     Rural
# 6420  72120  34.89895  -92.24110       33310     Rural
# 7984  99576  59.99005 -158.39443        2494     Urban
# 8281  12084  42.70419  -73.90089        4959     Urban
# 8286  73530  34.24724  -99.02039         445  Suburban
# 8702  75165  32.36912  -96.79744       43498  Suburban
# 9032  32580  30.49585  -86.52384        4364  Suburban
#
#                           Timezone  \
# 192   America/Indiana/Indianapolis
# 292               America/New_York
# 1177                America/Denver
# 1215              America/New_York
# 1989  America/Indiana/Indianapolis
# 2925               America/Chicago
# 3718              America/New_York
# 4014              America/New_York
# 4271               America/Chicago
# 4301           America/Los_Angeles
# 4958               America/Chicago
# 4999                America/Denver
# 5293               America/Chicago
# 5598              America/New_York
# 5738              America/New_York
# 6217                America/Denver
# 6420               America/Chicago
# 7984             America/Anchorage
# 8281              America/New_York
# 8286               America/Chicago
# 8702               America/Chicago
# 9032               America/Chicago
#
#                                                    Job  Children   Age  \
# 192                                       Sports coach       NaN   NaN
# 292                       Trade union research officer       NaN   NaN
# 1177                              Engineer, electrical       NaN   NaN
# 1215                         Teacher, secondary school       1.0   NaN
# 1989                             Scientist, biomedical       NaN   NaN
# 2925                                         Homeopath       NaN   NaN
# 3718                                      Photographer       4.0   NaN
# 4014  Administrator, charities/voluntary organisations       1.0   NaN
# 4271                          Insurance claims handler       NaN   NaN
# 4301                          Scientist, water quality       NaN   NaN
# 4958              Accountant, chartered public finance       NaN   NaN
# 4999                                     Hotel manager       NaN   NaN
# 5293                               Structural engineer       1.0   NaN
# 5598                          Computer games developer       NaN   NaN
# 5738                        Lecturer, higher education       NaN  32.0
# 6217                        Horticulturist, commercial       NaN   NaN
# 6420                        Museum/gallery conservator       NaN  41.0
# 7984                                   Hospital doctor       NaN   NaN
# 8281                          Arts development officer       NaN   NaN
# 8286                               Structural engineer       NaN   NaN
# 8702                                       Music tutor       NaN   NaN
# 9032                                           Midwife       NaN  60.0
#
#                                      Education  Employment    Income  \
# 192                Regular High School Diploma   Full Time       NaN
# 292   Some College, 1 or More Years, No Degree   Full Time       NaN
# 1177  Some College, 1 or More Years, No Degree     Student       NaN
# 1215                        Associate's Degree   Full Time    826.01
# 1989  Some College, 1 or More Years, No Degree   Full Time       NaN
# 2925             GED or Alternative Credential   Full Time       NaN
# 3718                         Bachelor's Degree   Full Time       NaN
# 4014       9th Grade to 12th Grade, No Diploma   Full Time       NaN
# 4271  Some College, 1 or More Years, No Degree   Full Time       NaN
# 4301                           Master's Degree     Retired       NaN
# 4958  Some College, 1 or More Years, No Degree   Full Time  38572.45
# 4999               Regular High School Diploma  Unemployed  65054.22
# 5293                        Associate's Degree     Student  16951.83
# 5598               Regular High School Diploma   Full Time       NaN
# 5738               Regular High School Diploma   Full Time       NaN
# 6217  Some College, 1 or More Years, No Degree   Full Time       NaN
# 6420  Some College, 1 or More Years, No Degree   Full Time       NaN
# 7984               Nursery School to 8th Grade     Retired  32065.15
# 8281  Some College, 1 or More Years, No Degree  Unemployed       NaN
# 8286               Nursery School to 8th Grade   Full Time       NaN
# 8702                        Associate's Degree     Student       NaN
# 9032                         Bachelor's Degree   Full Time       NaN
#
#             Marital  Gender ReAdmis  VitD_levels  Doc_visits  \
# 192        Divorced  Female      No    19.517493           5
# 292         Married    Male      No    14.251164           7
# 1177  Never Married  Female      No    19.338186           4
# 1215      Separated    Male      No    19.455420           2
# 1989      Separated    Male      No    17.737772           8
# 2925        Married  Female      No    18.480603           5
# 3718       Divorced  Female      No    16.301610           6
# 4014        Widowed  Female      No    15.968003           4
# 4271       Divorced    Male      No    48.482295           5
# 4301      Separated  Female      No    17.871485           6
# 4958      Separated    Male      No    18.465432           7
# 4999        Married    Male      No    19.851238           5
# 5293      Separated    Male     Yes    19.328903           5
# 5598        Married  Female      No    16.050932           5
# 5738        Married    Male     Yes    19.325875           4
# 6217      Separated  Female     Yes    17.146741           5
# 6420        Married  Female     Yes    14.423807           5
# 7984       Divorced  Female     Yes    17.909311           5
# 8281      Separated  Female     Yes    20.653276           6
# 8286      Separated    Male     Yes    14.010626           6
# 8702        Married    Male     Yes    18.556312           4
# 9032       Divorced    Male     Yes    19.190490           5
#
#       Full_meals_eaten  VitD_supp Soft_drink          Initial_admin HighBlood  \
# 192                  1          0        NaN    Emergency Admission       Yes
# 292                  0          0        NaN    Emergency Admission       Yes
# 1177                 0          1        NaN  Observation Admission        No
# 1215                 0          0        NaN     Elective Admission        No
# 1989                 0          0         No    Emergency Admission        No
# 2925                 2          0         No     Elective Admission        No
# 3718                 2          0        NaN    Emergency Admission        No
# 4014                 0          0        NaN  Observation Admission       Yes
# 4271                 0          1        NaN    Emergency Admission        No
# 4301                 0          1         No  Observation Admission        No
# 4958                 0          0        NaN  Observation Admission       Yes
# 4999                 0          3        NaN    Emergency Admission        No
# 5293                 0          0        NaN    Emergency Admission        No
# 5598                 3          0        NaN     Elective Admission       Yes
# 5738                 2          1        NaN  Observation Admission        No
# 6217                 0          1         No  Observation Admission        No
# 6420                 0          1        NaN    Emergency Admission       Yes
# 7984                 0          0         No    Emergency Admission        No
# 8281                 1          2         No    Emergency Admission        No
# 8286                 3          2        NaN     Elective Admission        No
# 8702                 0          0        NaN    Emergency Admission        No
# 9032                 0          0        NaN    Emergency Admission       Yes
#
#      Stroke Complication_risk  Overweight Arthritis Diabetes Hyperlipidemia  \
# 192      No            Medium         1.0       Yes       No             No
# 292     Yes            Medium         1.0       Yes       No            Yes
# 1177     No               Low         1.0        No      Yes            Yes
# 1215    Yes               Low         NaN        No       No            Yes
# 1989    Yes              High         1.0        No      Yes             No
# 2925     No              High         1.0        No       No             No
# 3718     No               Low         NaN        No       No            Yes
# 4014     No            Medium         NaN        No       No            Yes
# 4271     No               Low         0.0       Yes       No             No
# 4301     No               Low         1.0        No       No             No
# 4958    Yes              High         1.0        No       No            Yes
# 4999     No            Medium         NaN        No       No            Yes
# 5293     No            Medium         NaN        No       No             No
# 5598    Yes            Medium         NaN       Yes       No             No
# 5738     No            Medium         NaN       Yes      Yes             No
# 6217     No              High         NaN        No      Yes             No
# 6420     No            Medium         NaN       Yes      Yes            Yes
# 7984    Yes              High         NaN        No       No            Yes
# 8281    Yes            Medium         0.0        No       No             No
# 8286     No              High         0.0       Yes       No             No
# 8702     No            Medium         1.0        No       No             No
# 9032     No               Low         NaN        No       No             No
#
#      BackPain  Anxiety Allergic_rhinitis Reflux_esophagitis Asthma  \
# 192        No      NaN               Yes                 No    Yes
# 292       Yes      NaN               Yes                 No    Yes
# 1177       No      NaN                No                 No     No
# 1215       No      NaN                No                 No    Yes
# 1989       No      NaN               Yes                 No     No
# 2925       No      NaN               Yes                 No     No
# 3718      Yes      1.0                No                 No     No
# 4014       No      NaN                No                 No     No
# 4271      Yes      0.0               Yes                 No     No
# 4301       No      NaN                No                 No     No
# 4958      Yes      NaN                No                 No     No
# 4999      Yes      1.0                No                 No     No
# 5293      Yes      NaN               Yes                 No     No
# 5598      Yes      NaN                No                 No     No
# 5738       No      1.0                No                 No    Yes
# 6217       No      NaN                No                Yes     No
# 6420       No      NaN                No                 No    Yes
# 7984       No      NaN               Yes                 No    Yes
# 8281      Yes      NaN               Yes                 No     No
# 8286      Yes      1.0               Yes                Yes     No
# 8702      Yes      NaN                No                Yes     No
# 9032      Yes      0.0                No                 No     No
#
#          Services  Initial_days   TotalCharge  Additional_charges  Item1  \
# 192   Intravenous      1.028205   2472.817655        22040.917470      3
# 292    Blood Work     26.094601   4964.499903        16895.368300      3
# 1177  Intravenous     13.673667   3620.379709         7324.539487      2
# 1215   Blood Work           NaN   3201.958286         5986.913483      4
# 1989   Blood Work           NaN   3351.019270         6586.488870      5
# 2925  Intravenous           NaN   4005.349965        12776.266060      2
# 3718   Blood Work           NaN   4104.078624         4389.512479      3
# 4014  Intravenous     14.489697   2996.086015        21535.069150      4
# 4271   Blood Work           NaN  15814.319010         4024.218953      3
# 4301      CT Scan           NaN   2002.342363        11038.307940      3
# 4958      CT Scan           NaN   3083.744858        23722.715230      4
# 4999  Intravenous           NaN   3496.446225        15254.205760      4
# 5293   Blood Work           NaN   8400.806676         9168.617603      4
# 5598  Intravenous     53.896159   7016.353836        20699.060040      4
# 5738   Blood Work           NaN   8660.785794         5642.958203      4
# 6217  Intravenous     64.448515   7235.418734         7959.278206      4
# 6420   Blood Work     70.723250   7920.325998        14072.272520      4
# 7984   Blood Work           NaN   7335.094677        15800.867410      6
# 8281   Blood Work           NaN   7893.443309        13142.769020      3
# 8286      CT Scan           NaN   6996.477636        14266.440020      3
# 8702   Blood Work     56.894270   7289.511566         7142.632649      3
# 9032   Blood Work           NaN   7799.306055        19976.960410      3
#
#       Item2  Item3  Item4  Item5  Item6  Item7  Item8
# 192       4      4      5      4      3      4      4
# 292       3      3      4      3      4      4      4
# 1177      2      2      4      2      4      3      3
# 1215      4      3      3      4      2      5      2
# 1989      4      5      3      4      4      3      2
# 2925      3      4      3      3      3      3      1
# 3718      3      3      2      3      3      4      3
# 4014      3      3      4      4      3      4      4
# 4271      3      3      3      5      1      2      1
# 4301      4      2      4      2      4      3      6
# 4958      3      4      5      1      5      4      4
# 4999      4      4      4      2      3      3      4
# 5293      4      4      4      3      3      2      2
# 5598      4      3      4      5      3      3      4
# 5738      3      4      4      3      4      4      3
# 6217      4      5      4      5      5      4      3
# 6420      4      5      4      4      6      5      4
# 7984      5      6      3      4      5      4      5
# 8281      3      4      3      4      4      5      4
# 8286      3      4      4      4      3      4      2
# 8702      4      2      5      5      3      3      2
# 9032      2      3      5      4      4      4      3

# %% [markdown]
# **Getting value counts for columns with missing values**

# %%
columns_to_check = ['Children', 'Age', 'Income', 'Soft_drink', 'Overweight', 'Anxiety', 'Initial_days']

# Get value counts for each specified column
for column in columns_to_check:
    value_counts = df[column].value_counts()
    print(f"{column}:\n{value_counts}\n")
# Out:
# Children:
# 0.0     1880
# 1.0     1858
# 3.0     1113
# 2.0     1094
# 4.0      739
# 8.0      157
# 7.0      154
# 6.0      145
# 5.0      126
# 9.0       83
# 10.0      63
# Name: Children, dtype: int64
#
# Age:
# 30.0    126
# 47.0    124
# 74.0    123
# 38.0    123
# 40.0    122
#        ...
# 75.0     90
# 82.0     90
# 63.0     90
# 51.0     89
# 36.0     85
# Name: Age, Length: 72, dtype: int64
#
# Income:
# 14572.40    2
# 37132.97    2
# 55506.92    2
# 20474.03    2
# 26915.85    2
#            ..
# 35093.92    1
# 41900.29    1
# 13511.95    1
# 34015.88    1
# 62682.63    1
# Name: Income, Length: 7531, dtype: int64
#
# Soft_drink:
# No     5589
# Yes    1944
# Name: Soft_drink, dtype: int64
#
# Overweight:
# 1.0    6395
# 0.0    2623
# Name: Overweight, dtype: int64
#
# Anxiety:
# 0.0    6110
# 1.0    2906
# Name: Anxiety, dtype: int64
#
# Initial_days:
# 10.585770    1
# 64.630142    1
# 48.772686    1
# 67.036508    1
# 63.334689    1
#             ..
# 9.216747     1
# 1.021594     1
# 10.261690    1
# 17.170461    1
# 70.850592    1
# Name: Initial_days, Length: 8944, dtype: int64

# %% [markdown]
# **Checking summary statistics for columns with missing values**

# %%
# Get summary statistics for the specified columns
summary_stats = df[columns_to_check].describe()
print(summary_stats)
# Out:
#           Children          Age         Income   Overweight      Anxiety  \
# count  7412.000000  7586.000000    7536.000000  9018.000000  9016.000000
# mean      2.098219    53.295676   40484.438268     0.709137     0.322316
# std       2.155427    20.659182   28664.861050     0.454186     0.467389
# min       0.000000    18.000000     154.080000     0.000000     0.000000
# 25%       0.000000    35.000000   19450.792500     0.000000     0.000000
# 50%       1.000000    53.000000   33942.280000     1.000000     0.000000
# 75%       3.000000    71.000000   54075.235000     1.000000     1.000000
# max      10.000000    89.000000  207249.130000     1.000000     1.000000
#
#        Initial_days
# count   8944.000000
# mean      34.432082
# std       26.287050
# min        1.001981
# 25%        7.911709
# 50%       34.446941
# 75%       61.124654
# max       71.981486

# %% [markdown]
# **Rechecking distribution for columns with missing values**
#
# Income is left skewed.<br> The median should be used for imputation<br>
# Initial Days has a bimodal distribution.

# %%
# Create a loop to create visualizations for each column
for column in columns_to_check:
    plt.figure(figsize=(10, 6))  # Increase the figure size
    if pd.api.types.is_numeric_dtype(df[column]):
        # Create a histogram for numeric columns
        plt.hist(df[column], bins=20, color='skyblue', edgecolor='black')
        plt.title(f"Histogram of {column}")
        plt.xlabel(column)
        plt.ylabel("Frequency")
    else:
        # Create a count plot for categorical columns
        sns.countplot(data=df, x=column, palette='viridis')
        plt.title(f"Count Plot of {column}")
        plt.xlabel(column)
        plt.ylabel("Count")
        plt.xticks(rotation=45, ha='right')  # Rotate and align the x-axis labels

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### **Check for Duplicated Rows**

# %% [markdown]
# Checking for duplicate rows using the duplicated() function and counting the occurrences of duplicates using sum()

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated()

# Count the occurrences of duplicates
num_duplicates = duplicate_rows.sum()

print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ##### **Checking Value Counts**

# %%
# Get value counts for each column
for column in df.columns:
    value_counts = df[column].value_counts()
    print(f"Value counts for column '{column}':")
    print(value_counts)
    print()
# Out:
# Value counts for column 'Unnamed: 0':
# 1        1
# 6671     1
# 6664     1
# 6665     1
# 6666     1
#         ..
# 3334     1
# 3335     1
# 3336     1
# 3337     1
# 10000    1
# Name: Unnamed: 0, Length: 10000, dtype: int64
#
# Value counts for column 'CaseOrder':
# 1        1
# 6671     1
# 6664     1
# 6665     1
# 6666     1
#         ..
# 3334     1
# 3335     1
# 3336     1
# 3337     1
# 10000    1
# Name: CaseOrder, Length: 10000, dtype: int64
#
# Value counts for column 'Customer_id':
# C412403    1
# D294364    1
# B203210    1
# C20177     1
# K216020    1
#           ..
# J694995    1
# N704840    1
# A197688    1
# H115454    1
# I569847    1
# Name: Customer_id, Length: 10000, dtype: int64
#
# Value counts for column 'Interaction':
# 8cd49b13-f45a-4b47-a2bd-173ffa932c2f    1
# dc1799a6-61d1-44a3-9b94-b89584baddfc    1
# dc6bab10-659b-4c78-ba87-87ffa3def32f    1
# 1cb70cc8-47b7-4192-8bed-faad0f27ab3b    1
# 06d0da86-5600-472d-a35d-7632775b5cd7    1
#                                        ..
# 2d5c049d-0431-443f-a9d7-46f875998599    1
# 4ccc7838-5c2c-4a3c-9e3b-2a646cec157e    1
# 4767cd0e-626d-4c5a-834e-a948aba315c2    1
# 8b1e1ea3-e596-4a97-b2cb-7f9926e9fbee    1
# bc482c02-f8c9-4423-99de-3db5e62a18d5    1
# Name: Interaction, Length: 10000, dtype: int64
#
# Value counts for column 'UID':
# 3a83ddb66e2ae73798bdf1d705dc0932    1
# 5d85418e862aab28ed18975446153694    1
# 28970195a839f74e572d2f43bd7fcb71    1
# 24665d1c5070b579d0c190324599ca6d    1
# 2d42fd6803d96fcffe64d3fcaab430dc    1
#                                    ..
# ce28b38948f9737918e240d8ce6b275f    1
# d98f314ddd12ca99e05858219127a06e    1
# 43e47521f56f27d0fc8e00ba7141de1b    1
# ffd9be64812b5e36ba9367abe51be705    1
# 95663a202338000abdf7e09311c2a8a1    1
# Name: UID, Length: 10000, dtype: int64
#
# Value counts for column 'City':
# Houston             36
# San Antonio         26
# Springfield         22
# New York            21
# Miami               21
#                     ..
# Coyote               1
# Tiline               1
# Monon                1
# Sullivans Island     1
# Coraopolis           1
# Name: City, Length: 6072, dtype: int64
#
# Value counts for column 'State':
# TX    553
# CA    550
# PA    547
# NY    514
# IL    442
# OH    383
# MO    328
# FL    304
# VA    287
# IA    276
# MI    273
# MN    267
# NC    254
# GA    247
# KS    220
# WI    214
# KY    210
# WV    207
# OK    207
# IN    195
# TN    194
# AL    194
# WA    191
# AR    190
# NE    185
# CO    179
# NJ    176
# LA    173
# MA    149
# MS    134
# MD    131
# SC    128
# SD    123
# OR    122
# ME    122
# MT    112
# NM    110
# ID    109
# ND    108
# AZ    108
# CT     80
# NH     79
# UT     72
# AK     70
# VT     60
# NV     51
# WY     51
# PR     43
# HI     34
# DE     17
# RI     14
# DC     13
# Name: State, dtype: int64
#
# Value counts for column 'County':
# Jefferson      118
# Washington     100
# Franklin        93
# Los Angeles     88
# Montgomery      80
#               ...
# Jenkins          1
# Sully            1
# Panola           1
# Kandiyohi        1
# Sterling         1
# Name: County, Length: 1607, dtype: int64
#
# Value counts for column 'Zip':
# 25674    4
# 78104    4
# 68355    4
# 62098    4
# 24136    4
#         ..
# 18337    1
# 58442    1
# 71353    1
# 81612    1
# 15108    1
# Name: Zip, Length: 8612, dtype: int64
#
# Value counts for column 'Lat':
# 36.06702    4
# 33.34798    4
# 35.25512    4
# 39.38610    4
# 37.86890    4
#            ..
# 41.00911    1
# 39.20560    1
# 46.36035    1
# 34.96563    1
# 40.49998    1
# Name: Lat, Length: 8588, dtype: int64
#
# Value counts for column 'Lng':
# -121.28753    4
# -82.35159     4
# -85.99134     4
# -105.68001    4
# -89.03658     4
#              ..
# -74.87894     1
# -99.17911     1
# -91.81854     1
# -106.83727    1
# -80.19959     1
# Name: Lng, Length: 8601, dtype: int64
#
# Value counts for column 'Population':
# 0        109
# 195       14
# 115       11
# 178       11
# 285       11
#         ...
# 8092       1
# 11147      1
# 27175      1
# 7371       1
# 41524      1
# Name: Population, Length: 5951, dtype: int64
#
# Value counts for column 'Area':
# Rural       3369
# Suburban    3328
# Urban       3303
# Name: Area, dtype: int64
#
# Value counts for column 'Timezone':
# America/New_York                  3889
# America/Chicago                   3771
# America/Los_Angeles                937
# America/Denver                     612
# America/Detroit                    262
# America/Indiana/Indianapolis       151
# America/Phoenix                    100
# America/Boise                       86
# America/Anchorage                   50
# America/Puerto_Rico                 43
# Pacific/Honolulu                    34
# America/Menominee                   14
# America/Nome                        12
# America/Indiana/Vincennes            8
# America/Sitka                        6
# America/Kentucky/Louisville          6
# America/Toronto                      5
# America/Indiana/Tell_City            3
# America/Indiana/Marengo              3
# America/North_Dakota/Beulah          2
# America/Indiana/Winamac              1
# America/Indiana/Vevay                1
# America/North_Dakota/New_Salem       1
# America/Indiana/Knox                 1
# America/Yakutat                      1
# America/Adak                         1
# Name: Timezone, dtype: int64
#
# Value counts for column 'Job':
# Outdoor activities/education manager     29
# Exhibition designer                      27
# Theatre director                         27
# Scientist, audiological                  26
# Toxicologist                             25
#                                          ..
# Government social research officer        6
# Phytotherapist                            6
# Engineer, control and instrumentation     6
# Public relations account executive        6
# Licensed conveyancer                      6
# Name: Job, Length: 639, dtype: int64
#
# Value counts for column 'Children':
# 0.0     1880
# 1.0     1858
# 3.0     1113
# 2.0     1094
# 4.0      739
# 8.0      157
# 7.0      154
# 6.0      145
# 5.0      126
# 9.0       83
# 10.0      63
# Name: Children, dtype: int64
#
# Value counts for column 'Age':
# 30.0    126
# 47.0    124
# 74.0    123
# 38.0    123
# 40.0    122
#        ...
# 75.0     90
# 82.0     90
# 63.0     90
# 51.0     89
# 36.0     85
# Name: Age, Length: 72, dtype: int64
#
# Value counts for column 'Education':
# Regular High School Diploma                 2444
# Bachelor's Degree                           1724
# Some College, 1 or More Years, No Degree    1484
# 9th Grade to 12th Grade, No Diploma          832
# Associate's Degree                           797
# Master's Degree                              701
# Some College, Less than 1 Year               642
# Nursery School to 8th Grade                  552
# GED or Alternative Credential                389
# Professional School Degree                   208
# No Schooling Completed                       133
# Doctorate Degree                              94
# Name: Education, dtype: int64
#
# Value counts for column 'Employment':
# Full Time     6029
# Student       1017
# Part Time      991
# Unemployed     983
# Retired        980
# Name: Employment, dtype: int64
#
# Value counts for column 'Income':
# 14572.40    2
# 37132.97    2
# 55506.92    2
# 20474.03    2
# 26915.85    2
#            ..
# 35093.92    1
# 41900.29    1
# 13511.95    1
# 34015.88    1
# 62682.63    1
# Name: Income, Length: 7531, dtype: int64
#
# Value counts for column 'Marital':
# Widowed          2045
# Married          2023
# Separated        1987
# Never Married    1984
# Divorced         1961
# Name: Marital, dtype: int64
#
# Value counts for column 'Gender':
# Female                  5018
# Male                    4768
# Prefer not to answer     214
# Name: Gender, dtype: int64
#
# Value counts for column 'ReAdmis':
# No     6331
# Yes    3669
# Name: ReAdmis, dtype: int64
#
# Value counts for column 'VitD_levels':
# 17.802330    1
# 18.423248    1
# 15.954743    1
# 19.566698    1
# 19.221626    1
#             ..
# 18.107325    1
# 17.331743    1
# 49.013013    1
# 18.292722    1
# 20.421883    1
# Name: VitD_levels, Length: 10000, dtype: int64
#
# Value counts for column 'Doc_visits':
# 5    3823
# 6    2436
# 4    2385
# 7     634
# 3     595
# 8      61
# 2      58
# 1       6
# 9       2
# Name: Doc_visits, dtype: int64
#
# Value counts for column 'Full_meals_eaten':
# 0    3715
# 1    3615
# 2    1856
# 3     612
# 4     169
# 5      25
# 6       6
# 7       2
# Name: Full_meals_eaten, dtype: int64
#
# Value counts for column 'VitD_supp':
# 0    6702
# 1    2684
# 2     544
# 3      64
# 4       5
# 5       1
# Name: VitD_supp, dtype: int64
#
# Value counts for column 'Soft_drink':
# No     5589
# Yes    1944
# Name: Soft_drink, dtype: int64
#
# Value counts for column 'Initial_admin':
# Emergency Admission      5060
# Elective Admission       2504
# Observation Admission    2436
# Name: Initial_admin, dtype: int64
#
# Value counts for column 'HighBlood':
# No     5910
# Yes    4090
# Name: HighBlood, dtype: int64
#
# Value counts for column 'Stroke':
# No     8007
# Yes    1993
# Name: Stroke, dtype: int64
#
# Value counts for column 'Complication_risk':
# Medium    4517
# High      3358
# Low       2125
# Name: Complication_risk, dtype: int64
#
# Value counts for column 'Overweight':
# 1.0    6395
# 0.0    2623
# Name: Overweight, dtype: int64
#
# Value counts for column 'Arthritis':
# No     6426
# Yes    3574
# Name: Arthritis, dtype: int64
#
# Value counts for column 'Diabetes':
# No     7262
# Yes    2738
# Name: Diabetes, dtype: int64
#
# Value counts for column 'Hyperlipidemia':
# No     6628
# Yes    3372
# Name: Hyperlipidemia, dtype: int64
#
# Value counts for column 'BackPain':
# No     5886
# Yes    4114
# Name: BackPain, dtype: int64
#
# Value counts for column 'Anxiety':
# 0.0    6110
# 1.0    2906
# Name: Anxiety, dtype: int64
#
# Value counts for column 'Allergic_rhinitis':
# No     6059
# Yes    3941
# Name: Allergic_rhinitis, dtype: int64
#
# Value counts for column 'Reflux_esophagitis':
# No     5865
# Yes    4135
# Name: Reflux_esophagitis, dtype: int64
#
# Value counts for column 'Asthma':
# No     7107
# Yes    2893
# Name: Asthma, dtype: int64
#
# Value counts for column 'Services':
# Blood Work     5265
# Intravenous    3130
# CT Scan        1225
# MRI             380
# Name: Services, dtype: int64
#
# Value counts for column 'Initial_days':
# 10.585770    1
# 64.630142    1
# 48.772686    1
# 67.036508    1
# 63.334689    1
#             ..
# 9.216747     1
# 1.021594     1
# 10.261690    1
# 17.170461    1
# 70.850592    1
# Name: Initial_days, Length: 8944, dtype: int64
#
# Value counts for column 'TotalCharge':
# 3191.048774     1
# 7329.393066     1
# 8498.290160     1
# 8451.833926     1
# 7530.770634     1
#                ..
# 2065.518265     1
# 3409.593273     1
# 15289.590000    1
# 4383.419018     1
# 8700.856021     1
# Name: TotalCharge, Length: 10000, dtype: int64
#
# Value counts for column 'Additional_charges':
# 8013.787149     5
# 22000.064780    4
# 3241.339760     4
# 11303.682330    4
# 8755.123303     4
#                ..
# 20461.526600    1
# 13357.949060    1
# 5316.329223     1
# 24412.109160    1
# 11643.189930    1
# Name: Additional_charges, Length: 8888, dtype: int64
#
# Value counts for column 'Item1':
# 4    3455
# 3    3404
# 5    1377
# 2    1315
# 6     225
# 1     213
# 7      10
# 8       1
# Name: Item1, dtype: int64
#
# Value counts for column 'Item2':
# 3    3439
# 4    3351
# 5    1421
# 2    1360
# 1     213
# 6     204
# 7      12
# Name: Item2, dtype: int64
#
# Value counts for column 'Item3':
# 4    3464
# 3    3379
# 5    1358
# 2    1356
# 6     220
# 1     211
# 7      11
# 8       1
# Name: Item3, dtype: int64
#
# Value counts for column 'Item4':
# 3    3422
# 4    3394
# 5    1388
# 2    1346
# 6     231
# 1     207
# 7      12
# Name: Item4, dtype: int64
#
# Value counts for column 'Item5':
# 4    3446
# 3    3423
# 2    1380
# 5    1308
# 6     219
# 1     211
# 7      13
# Name: Item5, dtype: int64
#
# Value counts for column 'Item6':
# 4    3464
# 3    3371
# 5    1403
# 2    1319
# 6     220
# 1     213
# 7      10
# Name: Item6, dtype: int64
#
# Value counts for column 'Item7':
# 4    3487
# 3    3456
# 2    1345
# 5    1274
# 1     215
# 6     212
# 7      11
# Name: Item7, dtype: int64
#
# Value counts for column 'Item8':
# 3    3401
# 4    3337
# 5    1429
# 2    1391
# 6     221
# 1     209
# 7      12
# Name: Item8, dtype: int64

# %% [markdown]
# ##### **Checking for Outliers**

# %%
# Create an empty list to store DataFrames for potential outliers
potential_outliers_dfs = []

# Loop through each column in the DataFrame
for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        # Identify potential outliers for numerical columns using the IQR method
        potential_outliers = identify_outliers_iqr(df[column])
        if not potential_outliers.empty:
            potential_outliers_dfs.append(pd.DataFrame({'Column': [column], 'Potential_Outliers': [potential_outliers.to_list()]}))

# Concatenate the list of DataFrames into a single DataFrame
potential_outliers_df = pd.concat(potential_outliers_dfs, ignore_index=True)

# Display the DataFrame containing potential outliers
potential_outliers_df
# Out:
#                 Column                                 Potential_Outliers
# 0                  Lat  [63.67959, 61.38199, 62.3338, 18.27102, 60.909...
# 1                  Lng  [-170.48517, -123.43535, -148.52105, -122.7278...
# 2           Population  [40029, 35369, 40051, 38835, 40824, 49034, 457...
# 3             Children  [10.0, 9.0, 8.0, 10.0, 8.0, 10.0, 10.0, 8.0, 8...
# 4               Income  [167105.1, 122615.82, 132963.95, 128855.39, 13...
# 5          VitD_levels  [47.81347635, 25.51463527, 25.2687425, 25.5465...
# 6     Full_meals_eaten                           [7, 6, 6, 7, 6, 6, 6, 6]
# 7            VitD_supp  [3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 8          TotalCharge  [14804.31933, 14977.47866, 14391.61126, 14436....
# 9   Additional_charges  [28788.08031, 28102.9575, 28297.97033, 29021.2...
# 10               Item1  [1, 7, 1, 1, 1, 1, 6, 6, 6, 6, 1, 1, 1, 6, 1, ...
# 11               Item2  [1, 1, 1, 1, 1, 1, 6, 6, 1, 6, 6, 1, 1, 1, 1, ...
# 12               Item3  [1, 6, 6, 1, 1, 1, 1, 1, 1, 1, 1, 1, 6, 1, 6, ...
# 13               Item4  [6, 1, 1, 1, 6, 1, 6, 6, 1, 6, 6, 1, 6, 6, 6, ...
# 14               Item5  [6, 1, 6, 6, 6, 1, 6, 6, 1, 1, 6, 6, 6, 1, 1, ...
# 15               Item6  [6, 6, 6, 6, 1, 6, 6, 1, 1, 6, 6, 6, 1, 6, 6, ...
# 16               Item7  [6, 6, 1, 1, 1, 6, 1, 1, 6, 1, 6, 1, 1, 6, 6, ...
# 17               Item8  [6, 1, 1, 6, 6, 6, 6, 1, 6, 6, 1, 1, 6, 6, 6, ...

# %%
# Columns with potential outliers
columns_to_investigate = ['Children', 'Income', 'VitD_levels', 'Full_meals_eaten', 'VitD_supp']

# Create box plots for each column
plt.figure(figsize=(12, 8))
for i, column in enumerate(columns_to_investigate, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data=df[column])
    plt.title(f'Outliers of {column}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# # **Part III: Data Cleaning**

# %% [markdown]
# ## **Section D: Data Cleaning Process Summary**

# %% [markdown]
# ## **D1: Findings on Data Quality Issues** D

# %% [markdown]
# ### **Duplicated Rows**

# %% [markdown]
# There were no duplicated rows found in the dataset.
#
# There was a signficant number of rows with missing data. 76.87% of the rows in the dataset has missing values of some kind.
#
# | Metric                             | Value    |
# |------------------------------------|---------|
# | Count of rows with missing values   | 7687    |
# | Percentage of rows with missing values | 76.87% |

# %% [markdown]
# ### **Missing Data**

# %% [markdown]
# The missing data was present across 7 different columns.
#
# | Category      | Count     |
# |---------------|-----------|
# | Children      | 2588      |
# | Age           | 2414      |
# | Income        | 2464      |
# | Soft_drink    | 2467      |
# | Overweight    | 982       |
# | Anxiety       | 984       |
# | Initial_days  | 1056      |
#
# 37.89% of the dataset has rows with 2 or more missing values present.
#
# | Count of Missing Values | Count of Rows |
# |-------------------------|---------------|
# | Two or more             | 3789          |
# | Three or more           | 1219          |
# | Four or more            | 237           |
# | Five or more            | 22            |
# | Six or more             | 1             |
# | Seven or more           | 0             |
#
# Of the data missing the age and initial_days columns having missing data is of the most concern to me.

# %% [markdown]
# ### **Outliers**

# %% [markdown]
# The dataset contains potential outliers in the Children, Income, VitD_levels, Full_meals_eaten, VitD_supp columns however while these columns may contain outliers their values are within an acceptable range.<br><br> I.e it is possible for a patient to have 8-10 children or to have eaten 7 full meals in a day.<br><br>The outliers in the Vit_D_levels and VitD_supp columns also fall within a range I feel comfortable leaving in the dataset.

# %% [markdown]
# ### **Incorrect Data Types**

# %% [markdown]
# Children currently has a datatype of float64. This should be changed to int64 since these values should always be in whole numbers as it is not possible to have a fraction of a child<br><BR>
# Some of the columns that have yes/no responses are coded as objects with strings representing yes and no while others like Overweight and Anxiety have 0 and 1 representing yes and no. These columns need to be standardized across the dataset. They also need to be converted to int from either object or float. They should be recast as int
#
# Some columns representing categories like Education, Employment, Gender and Timezone are objects. While this is acceptable it would be better to recast them as categories with pandas

# %% [markdown]
# ### **Incorrect rounding in currency columns**

# %% [markdown]
# The values in the columns Income, Total_charge and Additional_charges should be rounded to two decimal places not six since they represent currency in dollars and cents

# %% [markdown]
# ## **D2: Justification for Data Quality Mitigation Methods**

# %% [markdown]
# I performed the cleaning tasks following order:<br>
#
# **Handle Categorical Columns with Binary Values<br>
# Fill Missing Values<br>
# Convert Data Types and Apply Formatting**<br><br>
#
# Handling the conversion of categorical columns with Yes/No to binary 0 and 1s makes the imputation of missing values later in the cleaning process easier. It also makes it easier to convert these columns to the correct data type later (int) and makes the data consistent across the data set.<br>
#
# I performed this step by creating a list of columns that needed to be transformed, created a replacement map to replace Yes with 1 and No with zero and then used the applymap function to peform the transformation.<P>
# <br>
# I then printed and displayed the applicable columns to ensure that all columns had been mapped correctly<P>
# <P><br>
# To address missing values, I opted to remove rows containing four or more missing values. This decision is grounded in the notion that when a considerable number of values are absent, the data integrity of those rows is significantly compromised. Hence, eliminating such instances enhances the overall quality and reliability of the dataset.<P>
# <P><br>
# I chose to remove all rows that had missing values in the Age column. My rationale for this is the one of the most important pieces of data in this dataset. Age loosely correlates to many other columns such as income, certain disease processes and whether a patient has children or not. <P>
# <P><br>
# Also considering that this is a medical dataset and that birthdate is usually a key piece of information used for identification for most patient interactions and that age can easily be calculated from that information then it's obmission from an observation makes me concerned about the data integrity of the entire row.<p>
# <P><br>
# Imputing either the mean or median in this case would be inappropriate because it would skew any findings we might make from the dataset in unintended and unpredictable ways. For these reasons I opted to remove these rows.<P>
# <P><br>
# I also chose to remove all rows that had missing values in the Initial_days column because the purpose of this dataset is to investigate the relationship between various factors and readmission. How many days a patient stays in the hospital for is an important factor in determining whether a patient will be readmitted at a later date.<P><P><br>
# While it is possible to imput values into this column based on summary statistics or using machine learning methods that makes inferences based on other columns such as the reason for admission we run the risk of baking assumptions into our data while will hinder future analysis. For this reason I chose to drop these values.<P><P><br>
# I filled in the null values in the Children, Soft_drink, Overweight and Anxiety columns with zero reprsenting no (after mapping the Yes/No values to 1 and 0). My rationale for this choice is that we wouldn't want to make an assumption that a patient has children when this has not been documented. For the other three columns in healthcare you wouldn't want to document a diagnosis that has not been made (Overweight and Anxiety) or an observation that has not been made (whether a patient drinks soft_drinks). This may skew the dataset towards 0 but will avoid coming to incorrect conclusions about the impact these factors have on readmission rates during later analysis.<br><br>
# For income I chose to imput the missing values using unsupervised learning by utilizing the MissForest module from the MissingPy package.  MissForest is a machine learning-based imputation technique. It uses a Random Forest algorithm to do the task. It is based on an iterative approach, and at each iteration the generated predictions are better. MissForest is better at handling right skewed data with outliers like the Income column better than other methods like KNN.<P><BR>
# I chose this method over other simplier methods like imputing the median or the mean to avoid skweing the dataset any further.<P><BR>
# I chose to round the currency based columns Income, Total_charge and Additional_charges to 2 decimal points to more accurately represent the data which is in dollars and cents.<P><BR>
# The final step was to correct any data types that needed to be int or categories.<p>

# %% [markdown]
# ## **Subsection D3: Outcome of Each Data-Cleaning**

# %% [markdown]
# The dataset now has zero duplicated values

# %% [markdown]
# All columns are now the correct datatype

# %% [markdown]
# There were no duplicated rows in the original dataset.<P>Currency columns have been rounded to 2 decimal points

# %% [markdown]
# ## **Subsection D4: Annotated Code for Mitigating Data Quality Issues**

# %%
#Load dataset into pandas dataframe
#Reloading dataframe at this point to make the cleaning process easier to roll back without having to rerun any previous analysis
df_cleaned = pd.read_csv('medical_raw_data.csv')

# %% [markdown]
# ### **Fill Missing Values**

# %% [markdown]
# #### Rows with more or more missing values need to be dropped from the dataset.

# %%
# Define the threshold for non-null values per row
threshold = len(df_cleaned.columns) - 3  # Keep rows with at least len(df_cleaned.columns) - 3 non-null values

# Drop rows with four or more missing values from the cleaned DataFrame
df_cleaned = df_cleaned.dropna(thresh=threshold)

# Verify the result
print("Original number of rows:", len(df))
print("Number of rows after dropping:", len(df_cleaned))
# Out:
# Original number of rows: 10000
# Number of rows after dropping: 9763

# %%
# Check for rows with multiple missing values

rows_with_four_or_more_missing_clean = df_cleaned[df_cleaned.isnull().sum(axis=1) >= 4]

# Get count of rows with four or more missing values
count_rows_with_four_or_more_missing_clean = len(df_cleaned[df_cleaned.isnull().sum(axis=1) >= 4])

print("Count of rows with four or more missing values:", count_rows_with_four_or_more_missing_clean)
# Out:
# Count of rows with four or more missing values: 0

# %% [markdown]
# #### Drop rows with missing values in the ages or intial_days columns

# %%
missing_values_age = df_cleaned['Age'].isna().sum()
missing_values_initial_days = df_cleaned['Initial_days'].isna().sum()

print("Missing values in Age column:", missing_values_age)
print("Missing values in Initial_days column:", missing_values_initial_days)
# Out:
# Missing values in Age column: 2254
# Missing values in Initial_days column: 944

# %% [markdown]
# The initial cleaning step had a minimal effect of missing values in the age or initial days columns

# %%
df_cleaned = df.dropna(subset=['Age', 'Initial_days'])

# %%
#Verifying that the missing values in the Age and Initial_days columns have been dropped.
missing_values_age = df_cleaned['Age'].isna().sum()
missing_values_initial_days = df_cleaned['Initial_days'].isna().sum()

print("Missing values in Age column:", missing_values_age)
print("Missing values in Initial_days column:", missing_values_initial_days)
# Out:
# Missing values in Age column: 0
# Missing values in Initial_days column: 0

# %% [markdown]
# #### **Impute values into Income columns using MissForest**

# %%
#Creates a copy of the dataframe so it can be compared to the results of the imputation
df_cleaned_pre_income_imputation = df_cleaned.copy()

# %%
# Select the 'Income' column as a DataFrame
income_data = df_cleaned[['Income']]

# %%
# Check for missing values in the 'Income' column
print(df_cleaned['Income'].isnull().sum())
# Out:
# 1662

# %%
# Suppress all warnings
warnings.filterwarnings("ignore")

# Select the columns that you want to use for imputation
columns_for_imputation = ['Age', 'Income', 'TotalCharge', 'Additional_charges' ]

# Create an instance of MissForest and fit it to your data
imputer = MissForest()
imputer.fit(df_cleaned[columns_for_imputation])

# Impute missing values
imputed_data = imputer.transform(df_cleaned[columns_for_imputation])

# Replace the columns with imputed values in the original DataFrame
df_cleaned[columns_for_imputation] = imputed_data

# Reset warnings to default behavior
warnings.resetwarnings()

# Now the 'Income' column should have its missing values imputed
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3

# %%
print(df_cleaned['Income'].sample(10))
# Out:
# 9510    16987.4800
# 5141    74245.5700
# 1393    34852.5603
# 5436    37986.5500
# 1193    96226.1500
# 5130    10861.4500
# 9517    17331.3800
# 743     39788.9700
# 1403    61239.9600
# 8897    96422.4000
# Name: Income, dtype: float64

# %%
# Describe the 'Income' column in the original df
original_income_stats = df_cleaned_pre_income_imputation['Income'].describe()

# Describe the 'Income' column in the df_cleaned dataset
cleaned_income_stats = df_cleaned['Income'].describe()

# Display the statistics for comparison
print("Original 'Income' Column Statistics:")
print(original_income_stats)
print()

print("Cleaned 'Income' Column Statistics:")
print(cleaned_income_stats)
# Out:
# Original 'Income' Column Statistics:
# count      5127.000000
# mean      40596.054234
# std       28881.883139
# min         154.080000
# 25%       19306.465000
# 50%       34174.230000
# 75%       54421.925000
# max      207249.130000
# Name: Income, dtype: float64
#
# Cleaned 'Income' Column Statistics:
# count      6789.000000
# mean      40820.113455
# std       25625.526945
# min         154.080000
# 25%       23495.970000
# 50%       37351.090000
# 75%       51300.810000
# max      207249.130000
# Name: Income, dtype: float64

# %%
# Set up the figure and axis
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Plot the histogram for both original and cleaned 'Income' columns
sns.histplot(df_cleaned_pre_income_imputation['Income'], bins=30, kde=True, color='blue', label='Pre-Imputation')
sns.histplot(df_cleaned['Income'], bins=30, kde=True, color='green', label='Cleaned')

# Add labels and legend
plt.title("'Income' Distribution Comparison")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.legend()

# Show the plot
plt.show()

# %%
# List of columns to transform
columns_to_transform = ['ReAdmis', 'HighBlood', 'Stroke',
                        'Arthritis', 'Diabetes', 'Hyperlipidemia', 'BackPain',
                        'Allergic_rhinitis', 'Reflux_esophagitis', 'Asthma', 'Soft_drink','Children','Overweight', 'Anxiety']

# Replace values in the specified columns using applymap
replacement_map = {'Yes': 1, 'No': 0}
df_cleaned[columns_to_transform] = df_cleaned[columns_to_transform].applymap(lambda x: replacement_map.get(x, x))

# Convert columns to integers and fill NaN values
int_columns = ['Soft_drink', 'Children', 'Overweight', 'Anxiety']
df_cleaned[int_columns] = df_cleaned[int_columns].fillna(0).astype(int)

# Print the modified DataFrame
print(df_cleaned)
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0              1          1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 1              2          2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 2              3          3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 3              4          4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 4              5          5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# ...          ...        ...         ...                                   ...
# 9993        9994       9994     Q117805  ccc85472-5bd1-4389-8442-122a876b9000
# 9994        9995       9995     M583491  15c2b4bb-2c36-41b2-b1e2-206144fae1dc
# 9995        9996       9996     B863060  a25b594d-0328-486f-a9b9-0567eb0f9723
# 9996        9997       9997     P712040  70711574-f7b1-4a17-b15f-48c54564b70f
# 9998        9999       9999     E344109  f5a68e69-2a60-409b-a92f-ac0847b27db0
#
#                                    UID          City State        County  \
# 0     3a83ddb66e2ae73798bdf1d705dc0932           Eva    AL        Morgan
# 1     176354c5eef714957d486009feabf195      Marianna    FL       Jackson
# 2     e19a0fa00aeda885b8a436757e889bc9   Sioux Falls    SD     Minnehaha
# 3     cd17d7b6d152cb6f23957346d11c3f07  New Richland    MN        Waseca
# 4     d2f0425877b10ed6bb381f3e2579424a    West Point    VA  King William
# ...                                ...           ...   ...           ...
# 9993  9612abd4b9a81c2fd596ec9adb232efa     Northvale    NJ        Bergen
# 9994  b9dd180aa8894ecea6af33a46b22e015     Fellsmere    FL  Indian River
# 9995  39184dc28cc038871912ccc4500049e5       Norlina    NC        Warren
# 9996  3cd124ccd43147404292e883bf9ec55c        Milmay    NJ      Atlantic
# 9998  2bb491ef5b1beb1fed758cc6885c167a         Quinn    SD    Pennington
#
#         Zip       Lat        Lng  Population      Area          Timezone  \
# 0     35621  34.34960  -86.72508        2951  Suburban   America/Chicago
# 1     32446  30.84513  -85.22907       11303     Urban   America/Chicago
# 2     57110  43.54321  -96.63772       17125  Suburban   America/Chicago
# 3     56072  43.89744  -93.51479        2162  Suburban   America/Chicago
# 4     23181  37.59894  -76.88958        5287     Rural  America/New_York
# ...     ...       ...        ...         ...       ...               ...
# 9993   7647  41.00669  -73.94259        5412     Urban  America/New_York
# 9994  32948  27.88942  -80.73347        7908     Urban  America/New_York
# 9995  27563  36.42886  -78.23716        4762     Urban  America/New_York
# 9996   8340  39.43609  -74.87302        1251     Urban  America/New_York
# 9998  57775  44.10354 -102.01593         271     Rural    America/Denver
#
#                                        Job  Children   Age  \
# 0         Psychologist, sport and exercise         1  53.0
# 1             Community development worker         3  51.0
# 2                  Chief Executive Officer         3  53.0
# 3                      Early years teacher         0  78.0
# 4              Health promotion specialist         0  22.0
# ...                                    ...       ...   ...
# 9993                       Legal executive         1  83.0
# 9994                      Technical author         6  69.0
# 9995                Programmer, multimedia         0  25.0
# 9996         Restaurant manager, fast food         4  87.0
# 9998  Outdoor activities/education manager         3  43.0
#
#                                      Education Employment    Income  \
# 0               Some College, Less than 1 Year  Full Time  86575.93
# 1     Some College, 1 or More Years, No Degree  Full Time  46805.99
# 2     Some College, 1 or More Years, No Degree    Retired  14370.14
# 3                GED or Alternative Credential    Retired  39741.49
# 4                  Regular High School Diploma  Full Time   1209.56
# ...                                        ...        ...       ...
# 9993                         Bachelor's Degree  Part Time  15654.69
# 9994               Regular High School Diploma  Full Time  39797.05
# 9995                         Bachelor's Degree    Student  45967.61
# 9996               Regular High School Diploma  Full Time  14983.02
# 9998                         Bachelor's Degree  Full Time  29702.32
#
#         Marital  Gender  ReAdmis  VitD_levels  Doc_visits  Full_meals_eaten  \
# 0      Divorced    Male        0    17.802330           6                 0
# 1       Married  Female        0    18.994640           4                 2
# 2       Widowed  Female        0    17.415889           4                 1
# 3       Married    Male        0    17.420079           4                 1
# 4       Widowed  Female        0    16.870524           5                 0
# ...         ...     ...      ...          ...         ...               ...
# 9993    Married    Male        0    20.231451           4                 1
# 9994  Separated    Male        0    17.229222           4                 0
# 9995    Widowed    Male        0    16.481612           4                 2
# 9996    Widowed    Male        1    18.451601           5                 0
# 9998   Divorced    Male        1    21.956305           5                 2
#
#       VitD_supp  Soft_drink        Initial_admin  HighBlood  Stroke  \
# 0             0           0  Emergency Admission          1       0
# 1             1           0  Emergency Admission          1       0
# 2             0           0   Elective Admission          1       0
# 3             0           0   Elective Admission          0       1
# 4             2           1   Elective Admission          0       0
# ...         ...         ...                  ...        ...     ...
# 9993          1           0  Emergency Admission          1       0
# 9994          2           0  Emergency Admission          0       0
# 9995          1           0  Emergency Admission          1       0
# 9996          0           0   Elective Admission          1       0
# 9998          1           0  Emergency Admission          0       0
#
#      Complication_risk  Overweight  Arthritis  Diabetes  Hyperlipidemia  \
# 0               Medium           0          1         1               0
# 1                 High           1          0         0               0
# 2               Medium           1          0         1               0
# 3               Medium           0          1         0               0
# 4                  Low           0          0         0               1
# ...                ...         ...        ...       ...             ...
# 9993              High           1          0         0               1
# 9994            Medium           0          1         0               0
# 9995            Medium           0          0         0               0
# 9996            Medium           1          1         1               0
# 9998            Medium           1          0         0               0
#
#       BackPain  Anxiety  Allergic_rhinitis  Reflux_esophagitis  Asthma  \
# 0            1        1                  1                   0       1
# 1            0        0                  0                   1       0
# 2            0        0                  0                   0       0
# 3            0        0                  0                   1       1
# 4            0        0                  1                   0       0
# ...        ...      ...                ...                 ...     ...
# 9993         0        0                  0                   0       0
# 9994         0        0                  0                   1       1
# 9995         0        1                  0                   1       0
# 9996         0        0                  0                   0       1
# 9998         1        0                  0                   0       0
#
#          Services  Initial_days  TotalCharge  Additional_charges  Item1  \
# 0      Blood Work     10.585770  3191.048774        17939.403420      3
# 1     Intravenous     15.129562  4214.905346        17612.998120      3
# 2      Blood Work      4.772177  2177.586768        17505.192460      2
# 3      Blood Work      1.714879  2465.118965        12993.437350      3
# 4         CT Scan      1.254807  1885.655137         3716.525786      2
# ...           ...           ...          ...                 ...    ...
# 9993   Blood Work     40.355300  6850.725648        27882.076380      6
# 9994   Blood Work     37.932116  5857.563763        12045.862390      2
# 9995  Intravenous     51.561217  6651.241294         8927.642189      3
# 9996      CT Scan     68.668237  7851.522660        28507.147340      3
# 9998   Blood Work     63.356903  8462.831883         7781.678412      5
#
#       Item2  Item3  Item4  Item5  Item6  Item7  Item8
# 0         3      2      2      4      3      3      4
# 1         4      3      4      4      4      3      3
# 2         4      4      4      3      4      3      3
# 3         5      5      3      4      5      5      5
# 4         1      3      3      5      3      4      3
# ...     ...    ...    ...    ...    ...    ...    ...
# 9993      6      5      3      3      5      5      5
# 9994      3      2      1      5      3      4      2
# 9995      2      2      3      4      3      4      2
# 9996      3      4      2      5      3      4      4
# 9998      5      3      4      4      3      4      3
#
# [6789 rows x 53 columns]

# %%
df_cleaned.isna().sum()
# Out:
# Unnamed: 0            0
# CaseOrder             0
# Customer_id           0
# Interaction           0
# UID                   0
# City                  0
# State                 0
# County                0
# Zip                   0
# Lat                   0
# Lng                   0
# Population            0
# Area                  0
# Timezone              0
# Job                   0
# Children              0
# Age                   0
# Education             0
# Employment            0
# Income                0
# Marital               0
# Gender                0
# ReAdmis               0
# VitD_levels           0
# Doc_visits            0
# Full_meals_eaten      0
# VitD_supp             0
# Soft_drink            0
# Initial_admin         0
# HighBlood             0
# Stroke                0
# Complication_risk     0
# Overweight            0
# Arthritis             0
# Diabetes              0
# Hyperlipidemia        0
# BackPain              0
# Anxiety               0
# Allergic_rhinitis     0
# Reflux_esophagitis    0
# Asthma                0
# Services              0
# Initial_days          0
# TotalCharge           0
# Additional_charges    0
# Item1                 0
# Item2                 0
# Item3                 0
# Item4                 0
# Item5                 0
# Item6                 0
# Item7                 0
# Item8                 0
# dtype: int64

# %% [markdown]
# ### **Handle Categorical Columns with Binary Values**

# %% [markdown]
# Note to reviewer. In my original submission I handled the applymap, filling null values and converting to int as 3 different steps but in my revised codes I am handling them as one step to avoid some chained assignment issues I was having with my dataframe but I am leaving the sections as reference

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6789 entries, 0 to 9998
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          6789 non-null   int64
#  1   CaseOrder           6789 non-null   int64
#  2   Customer_id         6789 non-null   object
#  3   Interaction         6789 non-null   object
#  4   UID                 6789 non-null   object
#  5   City                6789 non-null   object
#  6   State               6789 non-null   category
#  7   County              6789 non-null   object
#  8   Zip                 6789 non-null   int64
#  9   Lat                 6789 non-null   float64
#  10  Lng                 6789 non-null   float64
#  11  Population          6789 non-null   int64
#  12  Area                6789 non-null   category
#  13  Timezone            6789 non-null   category
#  14  Job                 6789 non-null   object
#  15  Children            6789 non-null   int32
#  16  Age                 6789 non-null   float64
#  17  Education           6789 non-null   category
#  18  Employment          6789 non-null   category
#  19  Income              6789 non-null   float64
#  20  Marital             6789 non-null   category
#  21  Gender              6789 non-null   category
#  22  ReAdmis             6789 non-null   int64
#  23  VitD_levels         6789 non-null   float64
#  24  Doc_visits          6789 non-null   int64
#  25  Full_meals_eaten    6789 non-null   int64
#  26  VitD_supp           6789 non-null   int64
#  27  Soft_drink          6789 non-null   int32
#  28  Initial_admin       6789 non-null   category
#  29  HighBlood           6789 non-null   int64
#  30  Stroke              6789 non-null   int64
#  31  Complication_risk   6789 non-null   category
#  32  Overweight          6789 non-null   int32
#  33  Arthritis           6789 non-null   int64
#  34  Diabetes            6789 non-null   int64
#  35  Hyperlipidemia      6789 non-null   int64
#  36  BackPain            6789 non-null   int64
#  37  Anxiety             6789 non-null   int32
#  38  Allergic_rhinitis   6789 non-null   int64
#  39  Reflux_esophagitis  6789 non-null   int64
#  40  Asthma              6789 non-null   int64
#  41  Services            6789 non-null   category
#  42  Initial_days        6789 non-null   float64
#  43  TotalCharge         6789 non-null   float64
#  44  Additional_charges  6789 non-null   float64
#  45  Item1               6789 non-null   int64
#  46  Item2               6789 non-null   int64
#  47  Item3               6789 non-null   int64
#  48  Item4               6789 non-null   int64
#  49  Item5               6789 non-null   int64
#  50  Item6               6789 non-null   int64
#  51  Item7               6789 non-null   int64
#  52  Item8               6789 non-null   int64
# dtypes: category(10), float64(8), int32(4), int64(25), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# #### **Fill in null values in the Children, Soft_drink, Overweight and Anxiety columns**

# %% [markdown]
# Replacement of null values in the Children, Soft_drink, Overweight and Anxiety columns were handled during the binary conversion process<P>
# In my first submission of this code I handled these tasks seperately so will leave this section in for reference.

# %%
columns_to_check = ['Children', 'Soft_drink', 'Overweight', 'Anxiety']

null_counts = df_cleaned[columns_to_check].isnull().sum()
print(null_counts)
# Out:
# Children      0
# Soft_drink    0
# Overweight    0
# Anxiety       0
# dtype: int64

# %% [markdown]
# ### **Convert Data Types and Apply Formatting**

# %% [markdown]
# #### **Apply Formatting**

# %% [markdown]
# #### **Correcting rounding in the currency based columns**

# %%
columns_to_format = ['TotalCharge', 'Additional_charges', 'Income']

# Create a copy of the DataFrame to work with
df_cleaned_copy = df_cleaned.copy()

# Apply formatting to the specified columns using .loc indexer on the copy
df_cleaned_copy.loc[:, columns_to_format] = df_cleaned_copy[columns_to_format].apply(lambda x: round(x, 2))

# Suppress the SettingWithCopyWarning warning
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=SettingWithCopyWarning)
    # Update the main DataFrame with the changes from the copy
    df_cleaned.update(df_cleaned_copy)

# Display the updated DataFrame
print(df_cleaned[columns_to_format])
# Out:
#       TotalCharge  Additional_charges    Income
# 0         3191.05            17939.40  86575.93
# 1         4214.91            17613.00  46805.99
# 2         2177.59            17505.19  14370.14
# 3         2465.12            12993.44  39741.49
# 4         1885.66             3716.53   1209.56
# ...           ...                 ...       ...
# 9993      6850.73            27882.08  15654.69
# 9994      5857.56            12045.86  39797.05
# 9995      6651.24             8927.64  45967.61
# 9996      7851.52            28507.15  14983.02
# 9998      8462.83             7781.68  29702.32
#
# [6789 rows x 3 columns]

# %% [markdown]
# #### **Correcting datatypes**

# %% [markdown]
# Converting columns to categories

# %%
# List of columns to convert to category
columns_to_convert = ['Timezone', 'Job', 'Education', 'Employment', 'Marital', 'Gender', 'Initial_admin', 'Services', 'Area', 'Complication_risk']

# Suppress the SettingWithCopyWarning warning
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=SettingWithCopyWarning)
    # Convert specified columns to category
    df_cleaned[columns_to_convert] = df_cleaned[columns_to_convert].astype('category')

# Display the updated DataFrame
print(df_cleaned[columns_to_convert])
# Out:
#               Timezone                                   Job  \
# 0      America/Chicago      Psychologist, sport and exercise
# 1      America/Chicago          Community development worker
# 2      America/Chicago               Chief Executive Officer
# 3      America/Chicago                   Early years teacher
# 4     America/New_York           Health promotion specialist
# ...                ...                                   ...
# 9993  America/New_York                       Legal executive
# 9994  America/New_York                      Technical author
# 9995  America/New_York                Programmer, multimedia
# 9996  America/New_York         Restaurant manager, fast food
# 9998    America/Denver  Outdoor activities/education manager
#
#                                      Education Employment    Marital  Gender  \
# 0               Some College, Less than 1 Year  Full Time   Divorced    Male
# 1     Some College, 1 or More Years, No Degree  Full Time    Married  Female
# 2     Some College, 1 or More Years, No Degree    Retired    Widowed  Female
# 3                GED or Alternative Credential    Retired    Married    Male
# 4                  Regular High School Diploma  Full Time    Widowed  Female
# ...                                        ...        ...        ...     ...
# 9993                         Bachelor's Degree  Part Time    Married    Male
# 9994               Regular High School Diploma  Full Time  Separated    Male
# 9995                         Bachelor's Degree    Student    Widowed    Male
# 9996               Regular High School Diploma  Full Time    Widowed    Male
# 9998                         Bachelor's Degree  Full Time   Divorced    Male
#
#             Initial_admin     Services      Area Complication_risk
# 0     Emergency Admission   Blood Work  Suburban            Medium
# 1     Emergency Admission  Intravenous     Urban              High
# 2      Elective Admission   Blood Work  Suburban            Medium
# 3      Elective Admission   Blood Work  Suburban            Medium
# 4      Elective Admission      CT Scan     Rural               Low
# ...                   ...          ...       ...               ...
# 9993  Emergency Admission   Blood Work     Urban              High
# 9994  Emergency Admission   Blood Work     Urban            Medium
# 9995  Emergency Admission  Intravenous     Urban            Medium
# 9996   Elective Admission      CT Scan     Urban            Medium
# 9998  Emergency Admission   Blood Work     Rural            Medium
#
# [6789 rows x 10 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6789 entries, 0 to 9998
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          6789 non-null   int64
#  1   CaseOrder           6789 non-null   int64
#  2   Customer_id         6789 non-null   object
#  3   Interaction         6789 non-null   object
#  4   UID                 6789 non-null   object
#  5   City                6789 non-null   object
#  6   State               6789 non-null   object
#  7   County              6789 non-null   object
#  8   Zip                 6789 non-null   int64
#  9   Lat                 6789 non-null   float64
#  10  Lng                 6789 non-null   float64
#  11  Population          6789 non-null   int64
#  12  Area                6789 non-null   category
#  13  Timezone            6789 non-null   category
#  14  Job                 6789 non-null   category
#  15  Children            6789 non-null   int32
#  16  Age                 6789 non-null   float64
#  17  Education           6789 non-null   category
#  18  Employment          6789 non-null   category
#  19  Income              6789 non-null   float64
#  20  Marital             6789 non-null   category
#  21  Gender              6789 non-null   category
#  22  ReAdmis             6789 non-null   int64
#  23  VitD_levels         6789 non-null   float64
#  24  Doc_visits          6789 non-null   int64
#  25  Full_meals_eaten    6789 non-null   int64
#  26  VitD_supp           6789 non-null   int64
#  27  Soft_drink          6789 non-null   int32
#  28  Initial_admin       6789 non-null   category
#  29  HighBlood           6789 non-null   int64
#  30  Stroke              6789 non-null   int64
#  31  Complication_risk   6789 non-null   category
#  32  Overweight          6789 non-null   int32
#  33  Arthritis           6789 non-null   int64
#  34  Diabetes            6789 non-null   int64
#  35  Hyperlipidemia      6789 non-null   int64
#  36  BackPain            6789 non-null   int64
#  37  Anxiety             6789 non-null   int32
#  38  Allergic_rhinitis   6789 non-null   int64
#  39  Reflux_esophagitis  6789 non-null   int64
#  40  Asthma              6789 non-null   int64
#  41  Services            6789 non-null   category
#  42  Initial_days        6789 non-null   float64
#  43  TotalCharge         6789 non-null   float64
#  44  Additional_charges  6789 non-null   float64
#  45  Item1               6789 non-null   int64
#  46  Item2               6789 non-null   int64
#  47  Item3               6789 non-null   int64
#  48  Item4               6789 non-null   int64
#  49  Item5               6789 non-null   int64
#  50  Item6               6789 non-null   int64
#  51  Item7               6789 non-null   int64
#  52  Item8               6789 non-null   int64
# dtypes: category(10), float64(8), int32(4), int64(25), object(6)
# memory usage: 2.3+ MB

# %%
df_cleaned.sample(10)
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 8396        8397       8397     Y455001  9921f981-c314-414c-a78f-3bbe679573b5
# 6048        6049       6049     L826607  2691089d-feb4-465f-8d1a-5de7d7c97a82
# 6357        6358       6358     E478503  211b81a5-4c10-4aa8-9ba4-dd2a001057a5
# 9733        9734       9734     Y278440  5cc3b6b6-3aec-46fd-869f-7b86f2dccd4d
# 6508        6509       6509     T191666  b9de5930-e19e-46a9-b0ce-7311bb4e9ca7
# 693          694        694     L997443  1111d15f-3397-4f98-ae15-70bb499cb12c
# 9319        9320       9320     C102904  e171b229-6bd6-4283-b196-50381287c5fb
# 3500        3501       3501      F95099  ded5431f-1419-474f-8f67-3c1f5a09fcaa
# 9070        9071       9071     I863162  e234ed54-5bea-4712-94a4-2a47b42f4073
# 1848        1849       1849     Q950462  fb7a1bb1-b94c-49e0-b77f-1a0ce1de4137
#
#                                    UID            City State       County  \
# 8396  7909844b2aabfe436cd6a1ce41dca609      Somerville    AL       Morgan
# 6048  7f96bfe6feabdbb097f3adeab43832c2      Winchester    OH     Highland
# 6357  b767399f48e4dac41464896451bace5a             Gay    WV      Jackson
# 9733  0931b6e798d4c214d6e9cadcf7cb4fee          Marcus    IA     Cherokee
# 6508  5aef9f1f998d472b7db14e77564228f2         Seymour    MO      Webster
# 693   18023d7be774a5b1d17481037baafde3         Theresa    NY    Jefferson
# 9319  676a2427ea0cdda549e5acc8ae1b5d81   Newport Coast    CA       Orange
# 3500  c0f7be395341a1c5d64e66f0b493ad35  Little Meadows    PA  Susquehanna
# 9070  4037118d106f1589cf3d0bc7e563dff4         Carroll    NE        Wayne
# 1848  2b670aabd11157e7f6b01ef08e637ce0         Raymond    KS         Rice
#
#         Zip       Lat        Lng  Population      Area             Timezone  \
# 8396  35670  34.46094  -86.71906        6667     Urban      America/Chicago
# 6048  45697  38.93391  -83.66522        4759     Rural     America/New_York
# 6357  25244  38.77217  -81.54808         590     Urban     America/New_York
# 9733  51035  42.77881  -95.79952        1592     Urban      America/Chicago
# 6508  65746  37.14710  -92.77841        8652     Urban      America/Chicago
# 693   13691  44.22541  -75.78319        2878     Urban     America/New_York
# 9319  92657  33.59560 -117.83209        9670     Urban  America/Los_Angeles
# 3500  18830  41.95142  -76.10744         555  Suburban     America/New_York
# 9070  68723  42.28601  -97.21192         535     Urban      America/Chicago
# 1848  67573  38.26846  -98.41889         187     Rural      America/Chicago
#
#                                                 Job  Children   Age  \
# 8396       Conservation officer, historic buildings         0  19.0
# 6048                     Designer, ceramics/pottery         4  81.0
# 6357                          Forensic psychologist         0  50.0
# 9733                               Heritage manager         0  64.0
# 6508                              Medical secretary         2  18.0
# 693   Chartered legal executive (England and Wales)         3  37.0
# 9319                            Geologist, wellsite         0  83.0
# 3500                            Exhibition designer         0  70.0
# 9070                                     Orthoptist         1  37.0
# 1848                 Manufacturing systems engineer         0  89.0
#
#                                 Education  Employment    Income  \
# 8396          Regular High School Diploma  Unemployed  47631.18
# 6048        GED or Alternative Credential   Full Time  28413.20
# 6357                    Bachelor's Degree   Full Time  19200.78
# 9733          Regular High School Diploma   Full Time  21609.92
# 6508  9th Grade to 12th Grade, No Diploma  Unemployed  35578.93
# 693   9th Grade to 12th Grade, No Diploma   Full Time  18238.34
# 9319                    Bachelor's Degree   Full Time  23450.36
# 3500          Regular High School Diploma   Full Time  19528.17
# 9070                      Master's Degree   Full Time  12244.89
# 1848          Regular High School Diploma   Full Time  84023.00
#
#             Marital  Gender  ReAdmis  VitD_levels  Doc_visits  \
# 8396      Separated    Male        1    17.596856           5
# 6048        Married  Female        1    17.612189           6
# 6357      Separated    Male        1    15.314928           4
# 9733        Married  Female        1    17.599487           5
# 6508        Married    Male        0    20.007670           5
# 693         Widowed  Female        0    18.753939           5
# 9319  Never Married  Female        1    18.074905           6
# 3500        Widowed  Female        0    19.775502           4
# 9070        Married    Male        1    20.022095           7
# 1848        Widowed  Female        0    17.573528           6
#
#       Full_meals_eaten  VitD_supp  Soft_drink          Initial_admin  \
# 8396                 1          0           0    Emergency Admission
# 6048                 0          0           0    Emergency Admission
# 6357                 0          0           0    Emergency Admission
# 9733                 2          0           1    Emergency Admission
# 6508                 0          0           0  Observation Admission
# 693                  0          0           0    Emergency Admission
# 9319                 2          0           0    Emergency Admission
# 3500                 0          0           0    Emergency Admission
# 9070                 1          0           0  Observation Admission
# 1848                 2          0           0     Elective Admission
#
#       HighBlood  Stroke Complication_risk  Overweight  Arthritis  Diabetes  \
# 8396          0       0              High           1          0         0
# 6048          1       0              High           1          0         1
# 6357          1       1            Medium           1          0         0
# 9733          0       0            Medium           0          0         0
# 6508          0       0              High           1          0         1
# 693           0       0               Low           1          1         1
# 9319          0       0            Medium           1          1         0
# 3500          0       0              High           1          1         0
# 9070          1       1            Medium           1          0         1
# 1848          0       0               Low           1          0         0
#
#       Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 8396               0         1        0                  1
# 6048               0         0        0                  0
# 6357               0         0        0                  1
# 9733               1         1        0                  1
# 6508               1         1        0                  1
# 693                0         0        0                  1
# 9319               0         0        0                  1
# 3500               1         1        0                  0
# 9070               0         1        0                  0
# 1848               0         0        0                  1
#
#       Reflux_esophagitis  Asthma     Services  Initial_days  TotalCharge  \
# 8396                   0       0   Blood Work     71.342170      9311.88
# 6048                   0       1      CT Scan     71.319029      8303.24
# 6357                   0       0  Intravenous     70.101745      8632.06
# 9733                   1       0   Blood Work     62.934725      7726.46
# 6508                   0       0  Intravenous     50.693526      6937.59
# 693                    0       0      CT Scan      2.728882      3237.90
# 9319                   0       1   Blood Work     64.881321      7853.40
# 3500                   1       0  Intravenous      1.707357      3843.78
# 9070                   0       0   Blood Work     65.739873      7461.32
# 1848                   1       1      CT Scan      6.310485      2309.45
#
#       Additional_charges  Item1  Item2  Item3  Item4  Item5  Item6  Item7  \
# 8396             4248.72      5      5      3      3      3      5      5
# 6048            27326.85      3      4      4      1      3      3      1
# 6357            17505.11      5      3      5      5      2      5      4
# 9733            11074.87      5      5      4      5      3      5      5
# 6508             3808.16      5      5      5      3      5      5      4
# 693              6678.81      5      4      3      4      2      6      5
# 9319            14033.56      3      4      4      2      4      3      2
# 3500            12386.85      5      6      5      3      3      4      4
# 9070            12495.72      3      5      4      3      2      4      3
# 1848            14451.23      4      3      3      2      5      3      1
#
#       Item8
# 8396      4
# 6048      4
# 6357      3
# 9733      3
# 6508      7
# 693       5
# 9319      2
# 3500      5
# 9070      5
# 1848      3

# %% [markdown]
# ### **Subsection D5: Cleaned Dataset**

# %% [markdown]
# CSV file attached to submission

# %%
# Save the DataFrame as a CSV file
df_cleaned.to_csv('medical_cleaned.csv', index=False)

# %% [markdown]
# ### **Subsection D6: Limitations of Data Cleaning Process**

# %% [markdown]
# One of the limitations of the data cleaning process was having to drop null values in the age and initial_days columns. Ideally I could have preserved those rows by cross referencing with another source of data to fill those observations with the correct values. Removing those rows does remove some potentially valuable observations from the dataset.
#
# Using the MissForest imputation method to imput missing values into the Income column also comes with some disadvantages because there weren't many columns I could have the the data cross referenced with so I may have injected some unintended skew into my dataset unknowingly. <P>
# By imputing the missing values in the Children, Soft-drink, Overweight and Anxiety columns with zero I have skewed the data towards zero. This may mean I may miss some insight or correlation between these values and their impact on readmission.<P>
# Another limitation of the data cleaning process is not having access to the original data collectors or completely understand their intention when collecting the data. I attempted to apply some of my past domain knowledge from when I used to be a Hospice Nurse but my experience was limited to being a care provider rather than a health informatics nurse. I may have made some erronious connections or assumptions when cleaning the data.

# %% [markdown]
# ### **Subsection D7: Impact of Limitations on Analysis**

# %% [markdown]
# Because over 75% of the original dataset had rows with at least one missing value and many observations had to either be removed or replaced with various techniques the dataset has lost a lot of it's integrity and I may have unknowingly injected some bias into my dataset based on the assumptions I made when cleaning it that may limit further analysis.<P>
# I may have removed too much data that it may not be possible to run certain machine learning techniques.

# %% [markdown]
# ## **Section E: Application of Principal Component Analysis (PCA)**

# %%
df_pca = df_cleaned.copy()

# %% [markdown]
# ### **Subsection E1: Principal Components Identification**

# %%
# Select numerical columns for PCA
numerical_cols = [
    'VitD_levels',
    'VitD_supp',
    'Full_meals_eaten',
    'Doc_visits',
    'Initial_days',
    'TotalCharge',
    'Additional_charges',
    'Income'
] + ['Item1', 'Item2', 'Item3', 'Item4', 'Item5', 'Item6', 'Item7', 'Item8']

numerical_df = df_pca[numerical_cols]

# %%
# Normalize or standardize the features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_df)

# %%
# Apply PCA
num_principal_components = 16  # Choose the number of principal components
pca = PCA(n_components=num_principal_components)
principal_components = pca.fit_transform(scaled_data)

# %%
# Create a DataFrame with the principal components
pc_df = pd.DataFrame(data=principal_components, columns=[f"PC{i}" for i in range(1, num_principal_components + 1)])

# Display the DataFrame with principal components
print(pc_df)
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -1.537709 -1.170876  0.282949  0.214354  1.590992 -1.484766  0.734577
# 1    -0.369903 -0.690711 -0.086588  1.093030  0.371397  1.320320  0.581145
# 2    -0.211422 -1.412646 -0.747485  0.659041 -1.092121  0.789139  0.136829
# 3     2.411065 -1.392693  0.385571  0.378848 -0.684571  0.064962  0.869528
# 4    -2.388974 -1.644363 -0.189123 -1.398877  0.087069  0.766323 -0.845721
# ...        ...       ...       ...       ...       ...       ...       ...
# 6784  4.251836  0.540905  1.094579  0.654193  0.509100  2.356697 -0.409251
# 6785 -2.610493 -0.205420  1.442016 -1.360411  1.181638  1.674270  0.307745
# 6786 -2.112323  0.187228 -0.096813 -0.207142 -0.098074  1.114448  0.314365
# 6787 -0.679851  0.850935  1.459391 -0.197759  0.254606  1.123277 -1.054980
# 6788  0.812862  1.232919  0.977413 -0.184288 -0.189669  0.606274 -0.572416
#
#            PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0    -1.051044 -0.772789  1.272841 -0.351826  0.536934  0.005439  0.654088
# 1     0.591874  0.236829 -0.396110  0.247768  0.512237 -0.801295  0.335401
# 2    -0.320850 -0.915668 -0.695301  0.487883  0.359020  0.284402 -0.299389
# 3    -0.163567 -0.496246  1.065242 -0.645863  0.148949 -0.245198 -0.713650
# 4     2.921505 -0.942649  0.759127 -1.313073 -0.060046 -0.578125 -1.667762
# ...        ...       ...       ...       ...       ...       ...       ...
# 6784 -0.585028 -1.180426  0.585439 -0.127575  0.220910  0.262178  0.665940
# 6785  1.355676 -0.491963  0.552859 -2.224622  0.864393 -0.056954  0.323816
# 6786  0.658838  1.380815 -0.215504 -1.614029  0.225169 -0.323705  0.038291
# 6787 -2.264965 -1.428897  1.186935 -0.609504 -0.288481 -0.152093 -0.984668
# 6788  0.993295  1.119697 -0.635510 -0.204297 -0.704944 -0.776165  1.494012
#
#           PC15      PC16
# 0     0.172254 -0.022751
# 1    -0.620134  0.022749
# 2    -1.538087 -0.109450
# 3    -1.831700 -0.000058
# 4     0.053743 -0.041732
# ...        ...       ...
# 6784  0.115859  0.004793
# 6785 -0.751598  0.110154
# 6786  0.691669  0.102222
# 6787 -0.302813 -0.164399
# 6788  0.529349 -0.144694
#
# [6789 rows x 16 columns]

# %%
# Create a DataFrame to store the PCA loading values
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7', 'PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16'], index=numerical_cols)

# Display the loading values for the principal components
print(loadings.iloc[:, :])
# Out:
#                          PC1       PC2       PC3       PC4       PC5  \
# VitD_levels        -0.018237  0.528772  0.027260  0.367804 -0.067926
# VitD_supp          -0.005481  0.028987  0.006589 -0.153336  0.546989
# Full_meals_eaten    0.004879 -0.011611  0.035934  0.671861 -0.168054
# Doc_visits          0.002646  0.005915 -0.003897  0.072785  0.387889
# Initial_days       -0.023741  0.465997  0.052720 -0.419239  0.040777
# TotalCharge        -0.027186  0.703124  0.050894  0.005049 -0.014990
# Additional_charges -0.002649  0.019517 -0.014893  0.450376  0.386270
# Income             -0.003611  0.001590 -0.009916  0.063431  0.603985
# Item1               0.456631 -0.006925  0.291512  0.005652 -0.004564
# Item2               0.427875  0.000438  0.293567 -0.009136  0.010537
# Item3               0.398614 -0.013540  0.292188 -0.000511  0.009771
# Item4               0.147496  0.041385 -0.556420  0.010192 -0.019461
# Item5              -0.183197 -0.052069  0.582104 -0.001974  0.005161
# Item6               0.407237  0.037379 -0.173668  0.018952 -0.018657
# Item7               0.359170  0.032650 -0.159095 -0.008944  0.008743
# Item8               0.312475  0.018749 -0.178219 -0.034676  0.023270
#
#                          PC6       PC7       PC8       PC9      PC10  \
# VitD_levels        -0.199913  0.185063  0.321781 -0.347104  0.005570
# VitD_supp           0.479858 -0.122034  0.653203  0.039607  0.039490
# Full_meals_eaten    0.147223 -0.145610  0.118660  0.675976  0.063059
# Doc_visits         -0.612406 -0.683215  0.016148  0.011292 -0.035104
# Initial_days        0.202749 -0.200184 -0.363910  0.411571 -0.006564
# TotalCharge        -0.009267  0.006160 -0.010525  0.003532  0.003535
# Additional_charges  0.435485 -0.140110 -0.540578 -0.378689 -0.003764
# Income             -0.313151  0.632785 -0.159361  0.322906 -0.036113
# Item1               0.004411  0.013064  0.022293 -0.020250 -0.099986
# Item2               0.006633  0.009481 -0.016137 -0.013760 -0.160189
# Item3               0.012944  0.003058  0.008205  0.017933 -0.204094
# Item4               0.033897  0.003038  0.054289  0.035299 -0.393565
# Item5              -0.013591  0.007356  0.020738 -0.028187  0.120862
# Item6              -0.012012  0.004495  0.005178  0.019956 -0.047659
# Item7               0.017541 -0.044253 -0.018534 -0.017544  0.074518
# Item8              -0.046209  0.020083 -0.026599 -0.011586  0.858598
#
#                         PC11      PC12      PC13      PC14      PC15      PC16
# VitD_levels        -0.004140 -0.012339  0.018488  0.001127 -0.011769 -0.529633
# VitD_supp          -0.004837  0.030299  0.015969  0.011828 -0.009078  0.000498
# Full_meals_eaten   -0.009316 -0.017828  0.003498  0.024490 -0.003440  0.002249
# Doc_visits          0.024871 -0.000282 -0.006502  0.004027  0.008089  0.000297
# Initial_days        0.016283  0.007507 -0.021441  0.001360  0.024065 -0.466553
# TotalCharge         0.007424 -0.010467  0.001783 -0.010604  0.000160  0.708165
# Additional_charges  0.036768  0.009369 -0.020802 -0.016319  0.010753 -0.013095
# Income             -0.035520 -0.010491 -0.011275 -0.000281  0.010641 -0.001834
# Item1               0.070079 -0.005271 -0.040203  0.192610  0.807231  0.006184
# Item2               0.132297 -0.067975 -0.059583  0.628365 -0.532708  0.003101
# Item3               0.219676 -0.234634  0.352825 -0.667378 -0.199971 -0.007456
# Item4               0.338315 -0.359338 -0.506496 -0.072588  0.028470 -0.001588
# Item5              -0.044986 -0.082794 -0.732113 -0.243391 -0.068363  0.000021
# Item6              -0.076761  0.814681 -0.251581 -0.227834 -0.119306  0.000586
# Item7              -0.838806 -0.342198 -0.089699 -0.066157 -0.053472 -0.003909
# Item8               0.315722 -0.147524 -0.069334 -0.027107 -0.030471 -0.004189

# %%
# Display the loading values for the first 6 principal components
print(loadings.iloc[:, :6])
# Out:
#                          PC1       PC2       PC3       PC4       PC5       PC6
# VitD_levels        -0.018237  0.528772  0.027260  0.367804 -0.067926 -0.199913
# VitD_supp          -0.005481  0.028987  0.006589 -0.153336  0.546989  0.479858
# Full_meals_eaten    0.004879 -0.011611  0.035934  0.671861 -0.168054  0.147223
# Doc_visits          0.002646  0.005915 -0.003897  0.072785  0.387889 -0.612406
# Initial_days       -0.023741  0.465997  0.052720 -0.419239  0.040777  0.202749
# TotalCharge        -0.027186  0.703124  0.050894  0.005049 -0.014990 -0.009267
# Additional_charges -0.002649  0.019517 -0.014893  0.450376  0.386270  0.435485
# Income             -0.003611  0.001590 -0.009916  0.063431  0.603985 -0.313151
# Item1               0.456631 -0.006925  0.291512  0.005652 -0.004564  0.004411
# Item2               0.427875  0.000438  0.293567 -0.009136  0.010537  0.006633
# Item3               0.398614 -0.013540  0.292188 -0.000511  0.009771  0.012944
# Item4               0.147496  0.041385 -0.556420  0.010192 -0.019461  0.033897
# Item5              -0.183197 -0.052069  0.582104 -0.001974  0.005161 -0.013591
# Item6               0.407237  0.037379 -0.173668  0.018952 -0.018657 -0.012012
# Item7               0.359170  0.032650 -0.159095 -0.008944  0.008743  0.017541
# Item8               0.312475  0.018749 -0.178219 -0.034676  0.023270 -0.046209

# %%
# Calculate the covariance matrix
cov_matrix = np.dot(scaled_data.T, scaled_data) / (scaled_data.shape[0] - 1)

# Initialize a list to store eigenvalues
eigenvalues = []

# Loop through each eigenvector (principal component) in PCA components
for eigenvector in pca.components_:
    # Calculate the eigenvalue using eigenvector and covariance matrix
    eigenvalue = np.dot(eigenvector.T, np.dot(cov_matrix, eigenvector))
    eigenvalues.append(eigenvalue)

# The 'eigenvalues' list now contains the calculated eigenvalues for each principal component
for eigenvalue in eigenvalues:
    print(eigenvalue)
# Out:
# 2.9524236298020226
# 1.9779298013778421
# 1.6509085560312946
# 1.0439990205685308
# 1.0305308328221934
# 1.0073641003412872
# 0.9851201456390517
# 0.9734157579154946
# 0.9569780015015181
# 0.7703018350051067
# 0.6997919666931054
# 0.5837709904017051
# 0.5384196069596014
# 0.4736275310932252
# 0.32753681013736974
# 0.03023851447671234

# %% [markdown]
# ### **Subsection E2: Justification for Reduced Number of Principal Components**

# %%
explained_variance = pca.explained_variance_ratio_
num_components = len(explained_variance)

plt.figure(figsize=(10, 6))
plt.plot(range(1, num_components + 1), explained_variance, marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance')
plt.xticks(range(1, num_components + 1))
plt.grid(True)
plt.show()

# %% [markdown]
# I would reduce the number of principal components to 6 based on the elbow of the scree plot being at 4 but also pplying the Kaiser-Guttman rule and retain only those principal components whose corresponding eigenvalues are greater than or equal to 1.<p>
# Based on the scree plot alone choosing 4 PCs maybe too little so I feel 6 is the best compromise in this case.

# %% [markdown]
# | PC       | Eigenvalue |
# |----------|------------|
# | PC1      | 2.952      |
# | PC2      | 1.978      |
# | PC3      | 1.651      |
# | PC4      | 1.044      |
# | PC5      | 1.016      |
# | PC6      | 1.001      |
# | PC7      | 0.974      |
# | PC8      | 0.961      |
# | PC9      | 0.771      |
# | PC10     | 0.700      |
# | PC11     | 0.584      |
# | PC12     | 0.538      |
# | PC13     | 0.474      |
# | PC14     | 0.328      |
# | PC15     | 0.030      |

# %% [markdown]
# **Principal component loading for the first 6 principal components**

# %% [markdown]
# |                 |     PC1 |     PC2 |     PC3 |     PC4 |     PC5 |     PC6 |
# |:----------------|--------:|--------:|--------:|--------:|--------:|--------:|
# | VitD_levels     | -0.0182 |  0.5288 |  0.0273 |  0.3686 | -0.0572 | -0.2031 |
# | VitD_supp       | -0.0055 |  0.0290 |  0.0066 | -0.1624 |  0.5409 |  0.4888 |
# | Full_meals_eaten |  0.0049 | -0.0116 |  0.0360 |  0.6756 | -0.1538 |  0.1420 |
# | Doc_visits       |  0.0026 |  0.0059 | -0.0039 |  0.0657 |  0.4009 | -0.5962 |
# | Initial_days    | -0.0237 |  0.4660 |  0.0528 | -0.4195 |  0.0280 |  0.2061 |
# | TotalCharge     | -0.0272 |  0.7031 |  0.0509 |  0.0053 | -0.0153 | -0.0093 |
# | Additional_charges | -0.0026 |  0.0195 | -0.0149 |  0.4438 |  0.3885 |  0.4435 |
# | Income          | -0.0039 |  0.0028 | -0.0111 |  0.0452 |  0.6053 | -0.3177 |
# | Item1            |  0.4566 | -0.0069 |  0.2915 |  0.0058 | -0.0038 |  0.0038 |
# | Item2            |  0.4279 |  0.0004 |  0.2936 | -0.0094 |  0.0106 |  0.0065 |
# | Item3            |  0.3986 | -0.0135 |  0.2922 | -0.0006 |  0.0107 |  0.0123 |
# | Item4            |  0.1475 |  0.0414 | -0.5564 |  0.0107 | -0.0192 |  0.0331 |
# | Item5            | -0.1832 | -0.0521 |  0.5821 | -0.0021 |  0.0050 | -0.0133 |
# | Item6            |  0.4072 |  0.0374 | -0.1737 |  0.0192 | -0.0186 | -0.0122 |
# | Item7            |  0.3592 |  0.0327 | -0.1591 | -0.0089 |  0.0087 |  0.0183 |
# | Item8            |  0.3125 |  0.0188 | -0.1782 | -0.0356 |  0.0204 | -0.0445 |

# %% [markdown]
# PC1: The largest loading values are associated with "Item1," "Item2," "Item3," and "Item6," indicating that these original features contribute significantly to PC1. This component might represent some general health-related factors.<P>
#
# PC2: The major contributors to PC2 are "VitD_levels," "VitD_supp," and "TotalCharge," suggesting that this component could capture factors related to vitamin D levels and healthcare charges.<P>
#
# PC3: "Item4," "Item5," "Item7," and "Item8" have notable loadings in PC3. This component could represent variations in specific medical procedures or treatments.<P>
#
# PC4: PC4's primary contributors are "Full_meals_eaten" and "Initial_days," which could imply a relationship between dietary habits and the duration of initial hospital stays.<P>
#
# PC5: "Income" and "Item7" have substantial loadings in PC5. This component might capture patterns related to income and specific medical treatments.<P>
#
# PC6: PC6 appears to have contributions from "VitD_supp," "Additional_charges," and "Income." It might represent a combination of vitamin D supplementation, additional charges, and income-related factors<P>

# %% [markdown]
# ### **Subsection E3: Benefits of PCA**

# %% [markdown]
# PCA allows organizations to deal with larger complex datasets in a manageable way but transforming high-dimensional data into a smaller set of uncorrelated principal components. It helps simplify data representation and facilitates analysis. It makes data visualization easier and makes it simpler to identify patterns and relationships.<P>
#
# PCA helps with noise reduction, resulting in cleaner and more accurate insights.Its ability to reveal hidden patterns in the data contributes to uncovering valuable insights that might remain obscured in the original feature space.

# %% [markdown]
# # **Part IV: Supporting Documents**

# %% [markdown]
# ## **Section F: Video Demonstration**

# %% [markdown]
# https://wgu.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=d9302e16-f6d2-4794-a718-b05b01512423

# %% [markdown]
# ## **Section G: Acknowledgement of Third-Party Code**

# %% [markdown]
# No outside sources used

# %% [markdown]
# ##  **Section H: Acknowledgement of Content Sources**
# No outside sources used
